# %% [markdown]
# ## Loading Packages

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from preprocessing import *
from utils import *
import warnings

# plt.style.use('dark_background')
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading Data

# %%
path = "Data/"
universe_dict = universe_select(path, "Cu")

# %% [markdown]
# ## Preprocessing

# %%
# Renaming the columns to price
universe_dict = price_rename(universe_dict)
# Cleaning the dataset of any erroneous datapoints
universe_dict = clean_dict_gen(universe_dict)
# Making sure that all the points in the window have consistent lenght
universe_dict = truncate_window_length(universe_dict)
# Generate the full training dataset
df_full = generate_dataset(universe_dict, lag=5, lg_returns_only=False)
# Out:
# Included Instrument:
# cu_shfe
# cu_lme
# cu_comex_p
# cu_comex_s
# peso
# sol
# bdi
# ted
# vix
# skew
# gsci

# %% [markdown]
# The target column represents the log returns at one forecast length out in the future. This is as in the auto-regressive calculations log returns will be used as the sole input variable, so naming convention has been kept separate to avoid confusion.
#
# So if the forecast length is a one week prediction, then the log returns for +5 days will be the target variable.

# %%
# Visualise the plots
# visualise_universe(universe_dict)
df = df_full[["target_cu_lme"]]

# %%
df_full.head(5)
# df.head()
# Out:
#             price_cu_shfe  price_cu_lme  price_cu_comex_p  price_cu_comex_s  \
# date
# 2006-08-29        68160.0        7410.0             3.423           12440.0
# 2006-08-30        67650.0        7465.0             3.365           12440.0
# 2006-08-31        67630.0        7719.0             3.469           12377.0
# 2006-09-01        70140.0        7607.0             3.475           11788.0
# 2006-09-04        71240.0        7669.0             3.475           11788.0
#
#             price_peso  price_sol  price_bdi  price_ted  price_vix  \
# date
# 2006-08-29       537.5      3.246     3750.0      5.083      12.28
# 2006-08-30       538.0      3.235     3795.0      5.051      12.22
# 2006-08-31       540.5      3.243     3847.0      5.051      12.31
# 2006-09-01       537.7      3.243     3875.0      5.001      11.96
# 2006-09-04       536.0      3.243     3882.0      5.001      11.96
#
#             price_skew  ...  target_cu_lme  target_cu_comex_p  \
# ...

# %%
# Taking t-1 to be the value for t
df["persistance"] = df.shift(1)

# Calculating metrics for these columns
MSE, MAE, MDE = evaluate(df, "target_cu_lme", "persistance")

# %%
# Placing in results dataframe
results = pd.DataFrame(columns={"MSE", "MAE", "MDE"})
results.index.name = 'Name'
results.head()
results.loc["persistance"] = [MSE, MAE, MDE] 
results.head()
# Out:
#                   MSE       MDE      MAE
# Name
# persistance  0.000582  0.017126  0.46595

# %% [markdown]
# ## Inverse Log Returns Example

# %%
lag = 5
df_prices = df_full[["price_cu_lme"]]
print(df_full[["price_cu_lme", "target_cu_lme"]][:10])
# Out:
#             price_cu_lme  target_cu_lme
# date
# 2006-08-29        7410.0       0.069838
# 2006-08-30        7465.0       0.077432
# 2006-08-31        7719.0       0.040371
# 2006-09-01        7607.0       0.029277
# 2006-09-04        7669.0      -0.025488
# 2006-09-05        7946.0      -0.046232
# 2006-09-06        8066.0      -0.074823
# 2006-09-07        8037.0      -0.077319
# 2006-09-08        7833.0      -0.073077
# 2006-09-11        7476.0      -0.002277

# %%
df_full["inverse_price"] = None
df_full["inverse_price"][lag:] = inverse_log_returns(df_full[["price_cu_lme"]], df[["target_cu_lme"]], lag=5)

# %%
df_full[["price_cu_lme", "target_cu_lme", 'inverse_price']][:10]
# Out:
#             price_cu_lme  target_cu_lme inverse_price
# date
# 2006-08-29        7410.0       0.069838          None
# 2006-08-30        7465.0       0.077432          None
# 2006-08-31        7719.0       0.040371          None
# 2006-09-01        7607.0       0.029277          None
# 2006-09-04        7669.0      -0.025488          None
# 2006-09-05        7946.0      -0.046232          7946
# 2006-09-06        8066.0      -0.074823          8066
# 2006-09-07        8037.0      -0.077319          8037
# 2006-09-08        7833.0      -0.073077          7833
# 2006-09-11        7476.0      -0.002277          7476

# %%
plt.plot(df_full.index[lag:], df_full["inverse_price"][lag:], label="Inverse")
plt.plot(df_full.index, df_full[["price_cu_lme"]], ":", label="Original")
plt.legend()
plt.grid()
plt.show()

# %%
window_length = 10
window_start = 0
window_end = window_start + window_length
df_full.iloc[window_start:window_end]
# Out:
#             price_cu_shfe  price_cu_lme  price_cu_comex_p  price_cu_comex_s  \
# date
# 2006-08-29        68160.0        7410.0            3.4230           12440.0
# 2006-08-30        67650.0        7465.0            3.3650           12440.0
# 2006-08-31        67630.0        7719.0            3.4690           12377.0
# 2006-09-01        70140.0        7607.0            3.4750           11788.0
# 2006-09-04        71240.0        7669.0            3.4750           11788.0
# 2006-09-05        71660.0        7946.0            3.6510           11542.0
# 2006-09-06        73990.0        8066.0            3.7020           11943.0
# 2006-09-07        74860.0        8037.0            3.6655           12088.0
# 2006-09-08        74330.0        7833.0            3.5780           11958.0
# 2006-09-11        71760.0        7476.0            3.4340           13330.0
#
#             price_peso  price_sol  price_bdi  price_ted  price_vix  \
# date
# ...
