# %% [markdown]
# ## Loading Packages

# %%
from deeplearning import *
from livelossplot import PlotLosses
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from preprocessing import *
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from utils import *
import warnings

warnings.filterwarnings("ignore")

set_seed(42)
# Out:
# True

# %% [markdown]
# ### Insuring that training is done on GPU if available

# %%
device = 'cpu'
if torch.cuda.device_count() > 0 and torch.cuda.is_available():
    print("Cuda installed! Running on GPU!")
    device = 'cuda'
else:
    print("No GPU available!")
# Out:
# No GPU available!

# %% [markdown]
# ## Loading Data

# %%
path = "Data/Commodity_Data/"
universe_dict = universe_select(path, "Cu")

# %% [markdown]
# ## Preprocessing

# %%
# Renaming the columns to price
universe_dict = price_rename(universe_dict)

# Cleaning the dataset of any erroneous datapoints
universe_dict = clean_dict_gen(universe_dict)

# Making sure that all the points in the window have consistent length
universe_dict = truncate_window_length(universe_dict)

# Lg Returns Only
# df_full = generate_dataset(universe_dict, lg_returns_only=True, price_only=False)

# Price Only
df_full = generate_dataset(universe_dict, lg_returns_only=False, price_only=True)
# Out:
# Included Instrument:
# cu_shfe
# cu_lme
# cu_comex_p
# cu_comex_s
# peso
# sol
# bdi
# ted
# vix
# skew
# gsci

# %%
# Both Price and Log Returns
# df_full = generate_dataset(universe_dict, lg_returns_only=False, price_only=False)

# %%
# # Raw Price Target
# df_target = df_full[["price_cu_lme"]]
# df_target = df_target.shift(-5)

# # df_full = df_full[df_full.columns.drop(list(df_full.filter(regex='price')))]
# df_full[["target"]] = df_target

# %% [markdown]
# The target column represents the log returns at one forecast length out in the future for the instrument of interest (aluminium or copper prices on the London Metals Exchange).
#
# To normalise the independent variables, the 1 day log returns between closing prices have been used.

# %%
# Visualise the plots
# visualise_universe(universe_dict)
df = df_full[["target"]]

# %%
df_full.head(15)
# df_full.tail(5)
# Out:
#             price_cu_shfe  price_cu_lme  price_cu_comex_p  price_cu_comex_s  \
# date
# 2006-09-13        69540.0        7484.5            3.3925           15748.0
# 2006-09-14        71350.0        7439.0            3.3820           14180.0
# 2006-09-15        69400.0        7281.0            3.3165           14775.0
# 2006-09-18        69830.0        7459.0            3.4180           15263.0
# 2006-09-19        71470.0        7516.0            3.3755           17523.0
# 2006-09-20        69610.0        7474.0            3.3700           18091.0
# 2006-09-21        70170.0        7602.0            3.4220           19546.0
# 2006-09-22        71170.0        7601.0            3.4395           20627.0
# 2006-09-25        71130.0        7560.0            3.4475           20978.0
# 2006-09-26        70890.0        7708.0            3.4635           21326.0
# 2006-09-27        71020.0        7662.0            3.4755           20855.0
# 2006-09-28        71170.0        7500.0            3.4140           20646.0
# 2006-09-29        71030.0        7568.0            3.4590           20360.0
# 2006-10-02        71030.0        7523.0            3.4305           20113.0
# 2006-10-03        71030.0        7347.0            3.2865           20293.0
#
#             price_peso  price_sol  price_bdi  price_ted  price_vix  \
# date
# 2006-09-13      537.35     3.2530     4129.0      4.901      11.18
# 2006-09-14      537.73     3.2475     4207.0      4.926      11.55
# 2006-09-15      537.10     3.2480     4258.0      4.939      11.76
# 2006-09-18      537.10     3.2450     4279.0      4.949      11.78
# 2006-09-19      537.10     3.2450     4275.0      4.948      11.98
# 2006-09-20      537.80     3.2450     4244.0      4.937      11.39
# 2006-09-21      539.70     3.2480     4200.0      4.921      12.25
# 2006-09-22      538.50     3.2470     4136.0      4.924      12.59
# 2006-09-25      539.30     3.2490     4069.0      4.907      12.12
# 2006-09-26      538.10     3.2490     3979.0      4.875      11.53
# 2006-09-27      536.70     3.2520     3915.0      4.869      11.58
# 2006-09-28      536.75     3.2530     3911.0      4.853      11.72
# 2006-09-29      534.70     3.2500     3944.0      4.877      11.98
# 2006-10-02      533.10     3.2460     3956.0      4.891      12.57
# 2006-10-03      534.25     3.2460     3960.0      4.912      12.24
#
#             price_skew  price_gsci    target
# date
# 2006-09-13      120.44   438.38855 -0.001404
# 2006-09-14      119.47   433.72522  0.021675
# 2006-09-15      135.25   431.58291  0.043012
# 2006-09-18      127.35   434.97293  0.013450
# 2006-09-19      125.03   426.51240  0.025225
# 2006-09-20      122.71   418.32234  0.024843
# 2006-09-21      119.68   423.56908 -0.013508
# 2006-09-22      118.86   418.01647 -0.004351
# 2006-09-25      120.75   418.93144 -0.004906
# 2006-09-26      121.64   419.19717 -0.047967
# 2006-09-27      118.43   426.00390 -0.081970
# 2006-09-28      118.21   426.62993 -0.022791
# 2006-09-29      120.09   428.05329 -0.009826
# 2006-10-02      119.80   420.17342 -0.004530
# 2006-10-03      116.93   409.67885  0.017004

# %% [markdown]
# Normalise data
#
# Split into validation data and test data
#
# Use validation to tune hyperparameters
#
# Perform predictions on the test dataset

# %% [markdown]
# ### Creating dataset for pytorch

# %%
df_full = df_full.iloc[:500]

# %%
df_X = df_full.loc[:, df_full.columns != 'target']
df_y = df_full.loc[:, df_full.columns == 'target']
# df_y = df_target

# %% [markdown]
# ### PCA

# %%
# Reducing the dataset to containing a threshold 
# amount of variance
n_dim = dimension_selector(df_X, thresh=0.98)
df_X = dimension_reduce(df_X, n_dim)
# Out:
# Number of dimensions: 2
# Explained Variance: [0.96691511 0.03189887]
# Explained Variance Sum: 0.9988139831384066

# %% [markdown]
# ### Trial Method

# %%
df_X = df_full[["price_cu_lme", "price_cu_shfe", "target"]]
scaler = MinMaxScaler()
df_X = scaler.fit_transform(df_X)
print(df_X.shape)
df_y = df_X[:-5, 2]
df_X = df_X[:-5, :2]

# The input size of each time series window
series_length = 100

# Creating a data structure which is slices of input size
X_train = []
y_train = []

# For prototyping
length = int(len(df_X)/4)
# length = len(df_X)

for i in range(series_length, length):
    X_train.append(df_X[i-series_length:i, :])
    y_train.append(df_y[i])
    
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = torch.Tensor(X_train)
y_train = torch.Tensor(y_train)

print(X_train.shape, y_train.shape)
# Out:
# (3333, 3)
# torch.Size([732, 100, 2]) torch.Size([732])

# %%
print(df_X.shape)
print(df_y.shape)
# Out:
# (3328, 2)
# (3328,)

# %% [markdown]
# ### Chunking Series into Windows

# %%
# The input size of each time series window
series_length = 100

# Creating a data structure which is slices of input size
X_train = []
y_train = []

# For prototyping
# length = int(len(df_X)/10)
length = len(df_X)

for i in range(series_length, length):
    X_train.append(df_X.values[i-series_length:i, :])
    y_train.append(df_y.values[i, 0])
    
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = torch.Tensor(X_train)
y_train = torch.Tensor(y_train)

print(X_train.shape, y_train.shape)
# Out:
# torch.Size([3233, 100, 2]) torch.Size([3233])

# %% [markdown]
# ### Hyperparameters

# %%
# Hyperparameters
learning_rate = 1e-2
momentum = 0.5
weight_decay = 0

# Batch Parameters
batch_size = 128
test_batch_size = 1000

n_epochs = 2

# Model Parameters
num_features = len(df_X.columns)
hidden_dim = 64
num_layers = 2
output_dim = 1

# %% [markdown]
# ### Class for LSTM deep learning

# %%
class DeepLearning():
    """Class to perform training and validation for a given model
    :param
    model: nn.Module the model to be trained
    df_X
    df_y
    n_epochs,
    optimiser, 
    window_size,
    loss_function
    device
    seed=42
    debug
    """
    
    def __init__(self, model, df_X, df_y,
                 n_epochs,
                 optimiser, 
                 window_size,
                 loss_function=torch.nn.MSELoss(size_average=False),
                 device="cpu", 
                 seed=42,
                 debug = True, 
                 disp_freq=20,
                 fig_disp_freq=50):
        
        # The neural network architecture
        self.model = model
        
        # The optimiser for gradient descent
        self.optimiser = optimiser
        
        # Dataframe of training values
        self.df_X = df_X
        
        # Dataframe of target values
        self.df_y = df_y
        
        # The number of epochs
        self.n_epochs = n_epochs
   
        #self.optimiser = optimiser
        self.loss_function = loss_function
        
        # Whether to run on cpu or gpu
        self.device = device
        
        # The random seed to set
        self.seed = seed
        
        # To activate debug mode
        self.debug = debug
        
        # For training/val logs
        self.logs = {}
        
        # The array of predicted lists for each batch
        self.pred_list = None
        
        assert (type(self.df_X) == pd.DataFrame)
        assert (type(self.df_y) == pd.DataFrame)
        assert (len(self.df_X.index) == len(self.df_y.index))
        assert (len(self.df_X.index) > 0)
        
        self.X_train = None
        self.X_val = None
        self.X_test = None
        
        self.y_train = None
        self.y_val = None
        self.y_test = None
        
        self.window_size = window_size
        self.disp_freq = disp_freq
        self.fig_disp_freq = fig_disp_freq
        self.inspect = None
        
    def train_val_test(self):
        """Splits the dataframes in to a training, validation
        and test set and creates torch tensors from the underlying
        numpy arrays"""
        # Splitting the sets into train, test and validation
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.df_X, self.df_y, test_size=0.2, shuffle=False)
        
        self.X_train, self.X_val, self.y_train, self.y_val = train_test_split(self.X_train, self.y_train, test_size=0.25, shuffle=False)

        if self.debug:
            print("Train Length: \t\t%i\nValidation Length: \t%i\nTest Length:\t\t%i" 
                  % (len(X_train), len(X_val), len(X_test)))
        
        # Performs normalisation
        # This changes the types of the X_train/val/test 
        # from dataframe to arrays
        self.normalise()
        
        # Tensor of training data
        self.X_train = torch.from_numpy(self.X_train).float()
        self.y_train = torch.from_numpy(self.y_train.values).float()

        # Tensor of training labels
        self.X_val = torch.from_numpy(self.X_val).float()
        self.y_val = torch.from_numpy(self.y_val.values).float()

        #  Tensor of test data
        self.X_test = torch.from_numpy(self.X_test).float()
        self.y_test = torch.from_numpy(self.y_test.values).float()

        # Size Check
        if self.debug:
            print("\nInitial Size Check:")
            self.size_check()
    
    
    def size_check(self):
        """Checks the size of the datasets"""
        if self.debug:
            print("\nX Train Shape:\t\t", self.X_train.size())
            print("X Val Shape:\t\t", self.X_val.size())
            print("X Test Shape:\t\t", self.X_test.size())

            print("\ny Train Shape:\t\t", self.y_train.size())
            print("y Val Shape:\t\t", self.y_val.size())
            print("y Test Shape:\t\t", self.y_test.size())
    
    
    def normalise(self):
        """Normalizes the data using MaxMinScaler, which
            was chosen because it preserves the original 
            scale and doesn't reduce effect of outliers"""
        
        scaler = MinMaxScaler()
        
        # Normalize the validation and test set by the same
        # scale as the training data. Needed for training to
        # be correctly scaled
        
        self.X_train = scaler.fit_transform(self.X_train)
        self.X_val = scaler.transform(self.X_val)
        self.X_test = scaler.transform(self.X_test)
        
        """TODO implement output scaling for MTL because 
        otherwise the scale of the different outputs will
        lead to dominance of some tasks"""
        
    
    def create_data_loaders(self):
        """Forms iterators to pipeline in the data"""
        
        # Slices the datasets into their respective windows
        # Beginning at 0 with a step of 1, then rearranging the 
        # columns to be consisten with notation.
        self.X_train= self.X_train.unfold(0, self.window_size, 1).permute(0, 2, 1)
        self.X_val = self.X_val.unfold(0, self.window_size, 1).permute(0, 2, 1)
        self.X_test = self.X_test.unfold(0, self.window_size, 1).permute(0, 2, 1)
        
        # The target values also need to be lined up
        # This reduces the dataset by the window size
        # The [:,;,-1] it to take the value at the end
        # of the window now the beginning
        self.y_train = self.y_train.unfold(0, self.window_size, 1)[:, :, -1]
        self.y_val = self.y_val.unfold(0, self.window_size, 1)[:, :, -1]
        self.y_test = self.y_test.unfold(0, self.window_size, 1)[:, :, -1]
        
        print("\nTime Series Quantity: %i Rolling Window Size: %i Feature Number: %i"
             %(self.X_train.shape[0], self.X_train.shape[1], self.X_train.shape[2]))
        if self.debug:
            print("\nDataset Creation Size Check:")
            self.size_check()
            
        # Create tensor datasets
        train_dataset = TensorDataset(self.X_train, self.y_train)
        val_dataset = TensorDataset(self.X_val, self.y_val)
        test_dataset = TensorDataset(self.X_test, self.y_test)
        
        # Data loaders
        train_data_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=False)
        val_data_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
        test_data_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)
        
        return train_data_loader, val_data_loader, test_data_loader
    
    
    def train(self, train_data_loader):
        """Performs a single training cycle and returns the
        mean squared error loss for the training dataset"""
        # Sets the model to train mode
        self.model.train()
        
        train_loss = 0.
        
        # List of each batch predictions
        pred_list = []
        
        # The data loader creates batches of data to train
        for i_batch, (X_train_batch, y_train_batch) in enumerate(train_data_loader):
            
            #print('Batch : ', i_batch)
            
            # Sending the data to GPU if available
            X_train_batch = X_train_batch.to(self.device)
            y_train_batch = y_train_batch.to(self.device)
            
            # Zeros the gradients
            self.optimiser.zero_grad()

            # Need to set seed here to make deterministic
            set_seed(42)
        
            # Perform forward pass
            y_pred = self.model(X_train_batch)
            
            # Calculate loss for the batch
            loss = self.loss_function(y_pred, y_train_batch)   

            # Perform backward pass
            loss.backward()   

            # Adding the predictions for this batch to prediction list
            pred_list.append(y_pred)
            
            # Calculate the training loss
            train_loss += (loss * X_train_batch.size()[0]).detach().cpu().numpy()

            # Update Parameters
            self.optimiser.step()               
        
        # Converting an array of batches of predictions to a list of predictions
        self.pred_list = [single_pred for batch in pred_list for single_pred in batch.detach().numpy()]
        
        return train_loss/len(train_data_loader.dataset.tensors[0])
    
    
    def validate(self, val_data_loader):
        """Evaluates the performance of the network
        on unseen validation data"""
        # Set the model to evaluate mode
        self.model.eval()
        
        val_loss = 0.
        # The data loader creates batches of data to validate
        for X_val_batch, y_val_batch in val_data_loader:
            
            # Ensures that the gradients are not updated
            with torch.no_grad():
                
                # Sending the data to GPU if available
                X_val_batch = X_val_batch.to(self.device)
                y_val_batch = y_val_batch.to(self.device)
                print(y_val_batch.shape, y_val_batch)
                # Perform forward pass
                y_pred = self.model(X_val_batch)

                # Calculate loss for the batch
                loss = self.loss_function(y_pred, y_val_batch) 
                
                # Calculate the validation loss
                val_loss += (loss * X_val_batch.size()[0]).detach().cpu().numpy()
            
        return val_loss/len(val_data_loader.dataset.tensors[0])
    
    
    def live_pred_plot(self):
#         x_axis = np.array(range(len(self.pred_list)))
        plt.plot(self.pred_list, label="Predicted")
        plt.plot(self.y_train.numpy(), label="Observed")
        plt.legend()
        plt.show()
    
    def training_wrapper(self):
        
        # start timer
        start_time = time.time()

        # set seed
        set_seed(int(self.seed))
        
        # Create data loaders
        train_loader, val_loader, test_loader = learning.create_data_loaders()
        
        # Shows live plot of losses
        liveloss = PlotLosses()
        
        train_log = []
        val_log = []
        
        # Begin training
        for epoch in range(self.n_epochs):
            
            live_logs = {}
            
            train_loss = self.train(train_loader) 
            val_loss = self.validate(val_loader) 
            
            # For live plotting
            live_logs['' + 'log loss'] = train_loss.item()
            live_logs['val_' + 'log loss'] = val_loss.item()
            live_logs['time'] = time.time() - start_time
            #liveloss.update(self.logs)
            #liveloss.draw()
            
            train_log.append(train_loss.item())
            val_log.append(val_loss.item())
            self.logs["Training Loss"] = train_log
            self.logs["Validation Loss"] = val_log
            
            if (epoch % self.disp_freq == 0): 
                print("Epoch: %i Train MSE: %.5f Val MSE: %.5f  Time: %.3f" % (epoch, train_loss.item(),
                                                          val_loss.item(), (time.time() - start_time)))
                
            if (epoch % self.fig_disp_freq == 0):
                self.live_pred_plot()

# %%
print(learning.X_val.shape)
print(learning.X_train.shape)
print(learning.X_test.shape)
# Out:
# torch.Size([1, 100, 3])
# torch.Size([201, 100, 3])
# torch.Size([1, 100, 3])

# %%
class LSTM(nn.Module):
    """A Long Short Term Memory network
    model"""
        
    def __init__(self, num_features, hidden_dim, output_dim,
                 batch_size, series_length, 
                 dropout=0.1, num_layers=2, debug=True):
        
        super(LSTM, self).__init__()
        
        # Number of features
        self.num_features = num_features
        
        # Hidden dimensions
        self.hidden_dim = hidden_dim

        # Number of hidden layers
        self.num_layers = num_layers
        
        # The output dimensions
        self.output_dim = output_dim
        
        # Batch Size
        self.batch_size = batch_size
        
        # Length of sequence
        self.series_length = series_length
        
        # Dropout Probability
        self.dropout = dropout
        
        # Define the LSTM layer
        self.lstm = nn.LSTM(
            input_size = self.num_features, 
            hidden_size =self.hidden_dim,
            num_layers =self.num_layers)

        # Fully Connected Layer
        self.fc1 = nn.Linear(in_features=self.hidden_dim, 
                             out_features=self.hidden_dim)
        
        # Activation function
        self.act = nn.ReLU()
        
        # Output layer
        self.out = nn.Linear(in_features=self.hidden_dim, 
                             out_features=self.output_dim)
        
        """TODO Add fully connected layer and see if that improves"""
        
        
    def init_hidden(self, batch_size):
        """Initialised the hidden state to be zeros"""
        return (torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(device),
                torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(device))
    
    
    def forward(self, x):
        """Forward pass through the neural network"""
        
        """TODO Directly switch these variables in 
        the permute of the dataset"""
        
        # Adjust to a variable batch size 
        batch_size = x.size()[0]
        series_length = x.size()[1]
        
        #print("series_length, batch_size", series_length, batch_size)
        
        assert (series_length == self.series_length)
        
        """TODO Check output of contiguous and non 
        contigious memory"""
        
        # Keeps the dimensions constant regardless of batchsize
        x = x.contiguous().view(series_length, batch_size, -1) 

        # Initialises the hidden states
        h0, c0 = self.init_hidden(batch_size)
        
        # Pass through through lstm layer
        # Only the x is of interest
        x, (hn, cn) = self.lstm(x, (h0, c0))
        
        # Output is seq to seq but only want seq to val
        # So only use the final value of the lstm outputted
        # sequence
        x = x[-1]  
        
        # Fully connected hidden layer
        x = self.act(self.fc1(x))
        
        return self.out(x).view(-1)

# %%
model_lstm = LSTM(num_features=num_features, 
             hidden_dim=hidden_dim, 
             series_length = series_length,
             batch_size=batch_size,
             output_dim=output_dim, 
             num_layers=num_layers)

print("num_features %i \nhidden_dim %i\nseries_length %i \nbatch_size %i\noutput_dim %i \nnum_layers %i"
      % (num_features, hidden_dim, series_length, batch_size,output_dim, num_layers))

print('df_X ', df_X.values.shape, '\ndf_y', df_y.values.shape)
# Out:
# num_features 2
# hidden_dim 64
# series_length 100
# batch_size 128
# output_dim 1
# num_layers 2
# df_X  (3333, 2)
# df_y (3333, 1)

# %%
optimiser = torch.optim.Adam(model_lstm.parameters(), learning_rate)
# optimizer = optim.RMSprop(model_lstm.parameters(), lr=learning_rate, weight_decay=0.0)

"""Do I need to declare a data explicitly in the dataset"""
learning = DeepLearning(model=model_lstm, 
                        df_X=df_X, 
                        df_y=df_y, 
                        n_epochs=500,
                        optimiser=optimiser,
                        window_size=series_length,
                        debug=False, 
                        disp_freq=20,
                        fig_disp_freq=20)

# Splitting the data into the train, validation and test sets
learning.train_val_test()
learning.training_wrapper()
# Out:
# Time Series Quantity: 1900 Rolling Window Size: 100 Feature Number: 2
# torch.Size([128, 1]) tensor([[-5.5402e-03],
#         [-1.3774e-03],
#         [-6.2979e-03],
#         [ 1.9106e-02],
#         [ 3.1378e-03],
#         [ 5.0244e-03],
#         [ 2.1851e-02],
#         [-3.7390e-04],
#         [-2.5859e-02],
#         [-2.0908e-03],
#         [-2.6135e-02],
#         [-2.0957e-02],
#         [ 2.9913e-04],
#         [ 2.2163e-02],
#         [ 1.0854e-02],
#         [ 2.8049e-02],
#         [ 2.2487e-02],
#         [ 2.9978e-02],
#         [ 8.1127e-03],
#         [-7.3945e-05],
#         [-2.5411e-03],
#         [-2.3343e-02],
#         [-2.6023e-02],
#         [-1.0337e-02],
#         [ 4.2062e-03],
#         [-7.8109e-03],
#         [ 6.7570e-03],
#         [ 4.9775e-03],
#         [-1.8571e-03],
#         [-1.8426e-03],
#         [ 7.2577e-03],
#         [-7.6515e-03],
#         [ 1.1850e-03],
#         [ 1.0776e-03],
#         [ 1.1060e-03],
#         [-6.8861e-03],
#         [-7.7856e-03],
#         [-1.8527e-02],
#         [-1.7495e-02],
#         [-5.6543e-02],
#         [-3.1933e-02],
#         [-2.7814e-02],
#         [-3.0159e-02],
#         [-1.2091e-02],
#         [ 1.5936e-02],
#         [-9.2092e-03],
#         [ 9.9955e-03],
#         [ 6.4294e-03],
#         [-2.7580e-03],
#         [ 4.1739e-03],
#         [-1.6659e-03],
#         [-1.9468e-02],
#         [-8.7635e-03],
#         [-2.4148e-02],
#         [-1.3813e-02],
#         [-6.7697e-03],
#         [-4.4564e-03],
#         [-9.0767e-03],
#         [-1.5720e-04],
#         [-1.4282e-02],
#         [-5.1664e-03],
#         [ 2.6606e-03],
#         [ 1.0999e-03],
#         [ 1.0999e-03],
#         [-6.3082e-03],
#         [-2.5032e-02],
#         [-2.8055e-02],
#         [-2.9563e-02],
#         [-3.0655e-02],
#         [-2.4746e-02],
#         [-1.8272e-02],
#         [-4.6306e-02],
#         [-9.5569e-02],
#         [-8.3503e-02],
#         [-6.6806e-02],
#         [-6.6409e-02],
#         [-3.7307e-02],
#         [ 3.1877e-02],
#         [ 2.7247e-03],
#         [-3.8708e-02],
#         [-1.4201e-02],
#         [-4.8152e-02],
#         [-4.9743e-02],
#         [-4.7360e-02],
#         [-1.4427e-03],
#         [-1.8560e-02],
#         [ 4.7628e-02],
#         [ 3.7908e-02],
#         [ 5.5577e-02],
#         [ 2.3014e-02],
#         [ 2.8988e-02],
#         [-2.0180e-02],
#         [-2.1600e-02],
#         [ 1.5223e-03],
#         [ 1.4706e-02],
#         [ 1.3361e-02],
#         [ 9.7653e-03],
#         [ 2.6255e-02],
#         [ 2.4309e-03],
#         [-8.0266e-03],
#         [-1.3889e-02],
#         [ 2.4478e-02],
#         [ 7.5244e-03],
#         [ 2.5892e-02],
#         [ 3.7143e-02],
#         [ 4.1522e-02],
#         [ 7.1725e-03],
#         [ 1.0031e-02],
#         [-1.0277e-02],
#         [-2.7120e-02],
#         [-5.3302e-03],
#         [-9.1572e-03],
#         [-1.8423e-02],
#         [ 1.7059e-03],
#         [ 2.0005e-02],
#         [-5.0603e-03],
#         [ 2.8464e-03],
#         [-1.0306e-02],
#         [ 2.0858e-03],
#         [ 3.2038e-02],
#         [ 4.7496e-02],
#         [ 6.1627e-02],
#         [ 7.6694e-02],
#         [ 5.2394e-02],
#         [ 8.2291e-04],
#         [-7.0170e-03],
#         [-1.7895e-02],
#         [-1.3342e-02]])
# torch.Size([128, 1]) tensor([[-3.1522e-02],
#         [-1.2457e-02],
#         [-1.7053e-02],
#         [ 3.2925e-03],
#         [-6.6553e-03],
#         [ 1.9554e-03],
#         [ 8.7485e-03],
#         [-3.3321e-04],
#         [-2.1513e-02],
#         [-1.1177e-02],
#         [ 8.6903e-03],
#         [ 2.1443e-03],
#         [-2.5861e-03],
#         [-2.0171e-03],
#         [-9.9050e-03],
#         [-2.0733e-02],
#         [-6.2810e-03],
#         [ 1.3977e-02],
#         [ 3.1307e-02],
#         [ 4.3191e-02],
#         [ 6.8522e-02],
#         [ 6.1180e-02],
#         [ 5.4735e-02],
#         [ 5.5470e-02],
#         [ 3.6134e-02],
#         [ 6.0310e-03],
#         [-3.1243e-03],
#         [-6.7293e-03],
#         [-5.4532e-03],
#         [ 3.2424e-03],
#         [ 5.0745e-04],
#         [ 3.6310e-03],
#         [ 7.8508e-05],
#         [-3.7376e-02],
#         [-3.1054e-02],
#         [-2.4853e-02],
#         [-4.1173e-02],
#         [-3.4015e-02],
#         [-1.7299e-02],
#         [-2.1882e-02],
#         [-2.5527e-02],
#         [-2.4793e-02],
#         [-2.3254e-02],
#         [-1.2281e-02],
#         [-1.3080e-02],
#         [-3.0883e-02],
#         [-1.3116e-02],
#         [-1.2675e-02],
#         [-1.2140e-02],
#         [ 3.8672e-03],
#         [-7.1791e-03],
#         [-5.8378e-03],
#         [-2.6403e-02],
#         [-3.9599e-02],
#         [-5.0693e-02],
#         [-2.2026e-02],
#         [-4.3442e-02],
#         [-2.5788e-02],
#         [ 6.6156e-03],
#         [-5.6775e-04],
#         [ 3.1330e-03],
#         [ 1.8091e-02],
#         [ 2.5788e-02],
#         [-1.4326e-03],
#         [ 7.4858e-03],
#         [ 4.1189e-03],
#         [-1.7408e-04],
#         [-3.6624e-02],
#         [-7.6862e-02],
#         [-4.5189e-02],
#         [-2.8349e-02],
#         [-2.9326e-02],
#         [-4.4845e-04],
#         [ 3.9553e-02],
#         [-4.5374e-04],
#         [-1.3940e-02],
#         [-2.1427e-02],
#         [-2.0803e-02],
#         [-2.0363e-02],
#         [-3.0879e-02],
#         [-5.2874e-02],
#         [-3.9842e-02],
#         [-5.3767e-02],
#         [-2.7197e-02],
#         [-4.5977e-03],
#         [-9.5179e-05],
#         [-4.7765e-03],
#         [ 7.5109e-03],
#         [-1.0793e-02],
#         [-2.8136e-02],
#         [-1.4574e-02],
#         [-1.1073e-02],
#         [ 1.6035e-02],
#         [-2.3262e-02],
#         [ 1.2084e-03],
#         [ 0.0000e+00],
#         [-1.3080e-03],
#         [-3.6338e-02],
#         [-1.4887e-02],
#         [-3.5350e-02],
#         [-1.0095e-02],
#         [-1.8296e-02],
#         [-2.7342e-02],
#         [ 1.2633e-02],
#         [-6.5271e-03],
#         [ 9.9020e-03],
#         [ 1.6307e-02],
#         [ 3.5095e-02],
#         [-2.9959e-03],
#         [ 3.4362e-02],
#         [ 1.6859e-02],
#         [-2.9673e-03],
#         [ 3.1522e-03],
#         [ 5.4044e-02],
#         [ 4.6642e-02],
#         [ 2.8559e-02],
#         [ 4.9145e-02],
#         [ 3.1879e-02],
#         [-7.9249e-04],
#         [ 9.7504e-04],
#         [-2.0329e-03],
#         [-6.1448e-02],
#         [-5.0992e-02],
#         [-3.4975e-02],
#         [-3.7159e-02],
#         [-4.0202e-02],
#         [ 2.4746e-02],
#         [ 1.6253e-02]])
# torch.Size([128, 1]) tensor([[ 2.5510e-02],
#         [ 2.6287e-02],
#         [ 1.8178e-02],
#         [ 2.0478e-02],
#         [ 1.1586e-02],
#         [-1.9971e-02],
#         [-2.8070e-02],
#         [-8.6897e-03],
#         [-2.2935e-02],
#         [-1.3449e-03],
#         [ 4.5523e-03],
#         [ 5.6775e-03],
#         [-1.9164e-02],
#         [-1.0424e-02],
#         [-1.1845e-02],
#         [-1.6924e-02],
#         [-1.2553e-02],
#         [-2.3960e-02],
#         [-2.6871e-02],
#         [-3.3129e-02],
#         [-4.0032e-02],
#         [-3.7522e-02],
#         [-3.7543e-02],
#         [-3.3549e-02],
#         [-5.7688e-02],
#         [-4.9914e-02],
#         [-6.7391e-02],
#         [-3.8846e-02],
#         [-4.7336e-02],
#         [-3.9434e-02],
#         [-1.5981e-02],
#         [-1.5607e-02],
#         [ 0.0000e+00],
#         [-3.1534e-03],
#         [ 1.9042e-02],
#         [ 4.0463e-03],
#         [ 1.3145e-03],
#         [-1.9648e-02],
#         [ 4.3469e-03],
#         [-9.0642e-03],
#         [-1.1153e-02],
#         [ 3.2787e-03],
#         [ 6.2292e-03],
#         [ 1.9330e-02],
#         [ 2.2937e-02],
#         [-8.4749e-03],
#         [ 4.8980e-03],
#         [-1.0183e-02],
#         [-3.4093e-03],
#         [ 1.4793e-02],
#         [ 2.1941e-02],
#         [ 2.3712e-02],
#         [ 3.1952e-02],
#         [ 1.1733e-03],
#         [-9.0201e-03],
#         [ 1.5617e-02],
#         [ 4.0740e-03],
#         [ 3.2460e-03],
#         [ 3.2460e-03],
#         [-1.7040e-02],
#         [-1.8037e-02],
#         [-2.4642e-02],
#         [-3.9389e-02],
#         [-4.8604e-02],
#         [-5.1850e-02],
#         [-6.6972e-02],
#         [-5.1470e-02],
#         [-2.3370e-02],
#         [-3.5191e-02],
#         [-5.7102e-05],
#         [ 1.6616e-02],
#         [-7.3772e-03],
#         [ 2.9372e-03],
#         [ 2.7746e-02],
#         [ 9.3214e-03],
#         [ 2.9242e-02],
#         [ 5.3801e-02],
#         [ 2.3908e-02],
#         [ 2.6778e-02],
#         [ 3.3819e-02],
#         [ 1.9230e-03],
#         [ 9.1503e-03],
#         [ 3.2934e-02],
#         [ 1.3745e-02],
#         [ 9.2006e-03],
#         [-8.9321e-03],
#         [-4.1487e-02],
#         [-5.1947e-02],
#         [-2.7682e-02],
#         [-8.8725e-03],
#         [ 1.0358e-02],
#         [ 3.0649e-02],
#         [ 2.6912e-02],
#         [ 2.5738e-02],
#         [ 2.6970e-02],
#         [ 1.8841e-02],
#         [ 1.2669e-02],
#         [ 7.2945e-03],
#         [ 1.9382e-02],
#         [ 1.7016e-03],
#         [ 1.7119e-02],
#         [ 3.1873e-02],
#         [ 5.3899e-02],
#         [ 6.6065e-02],
#         [ 6.2255e-02],
#         [ 3.1284e-02],
#         [ 3.0282e-02],
#         [ 7.5773e-03],
#         [-1.0027e-02],
#         [-7.2651e-03],
#         [ 1.7727e-02],
#         [ 1.0106e-03],
#         [ 3.8915e-02],
#         [ 1.7494e-02],
#         [ 2.3360e-02],
#         [ 2.4174e-02],
#         [ 4.3340e-03],
#         [-2.3629e-02],
#         [-1.9401e-02],
#         [-2.2254e-02],
#         [-3.3685e-02],
#         [-1.3874e-02],
#         [-1.9580e-02],
#         [-2.3840e-02],
#         [-4.0544e-02],
#         [-2.5899e-02],
#         [-2.0294e-02],
#         [-4.5053e-02]])
# torch.Size([128, 1]) tensor([[-0.0412],
#         [-0.0213],
#         [-0.0009],
#         [ 0.0091],
#         [ 0.0384],
#         [ 0.0347],
#         [ 0.0360],
#         [ 0.0341],
#         [ 0.0297],
#         [ 0.0337],
#         [ 0.0436],
#         [ 0.0317],
#         [ 0.0038],
#         [-0.0164],
#         [-0.0116],
#         [ 0.0041],
#         [ 0.0115],
#         [-0.0091],
#         [-0.0069],
#         [-0.0316],
#         [-0.0482],
#         [-0.0749],
#         [-0.0493],
#         [-0.0337],
#         [-0.0371],
#         [-0.0401],
#         [-0.0105],
#         [-0.0069],
#         [-0.0202],
#         [-0.0073],
#         [-0.0103],
#         [-0.0156],
#         [-0.0080],
#         [ 0.0104],
#         [ 0.0190],
#         [ 0.0284],
#         [ 0.0308],
#         [ 0.0160],
#         [-0.0085],
#         [-0.0140],
#         [-0.0051],
#         [-0.0068],
#         [-0.0289],
#         [-0.0141],
#         [-0.0256],
#         [-0.0436],
#         [-0.0321],
#         [-0.0148],
#         [ 0.0131],
#         [ 0.0062],
#         [ 0.0101],
#         [ 0.0202],
#         [ 0.0356],
#         [ 0.0140],
#         [ 0.0533],
#         [ 0.0322],
#         [ 0.0140],
#         [ 0.0318],
#         [ 0.0289],
#         [ 0.0132],
#         [ 0.0437],
#         [ 0.0379],
#         [-0.0024],
#         [-0.0207],
#         [-0.0351],
#         [-0.0420],
#         [-0.0314],
#         [ 0.0108],
#         [ 0.0387],
#         [ 0.0519],
#         [ 0.0423],
#         [ 0.0400],
#         [ 0.0240],
#         [ 0.0072],
#         [ 0.0090],
#         [ 0.0021],
#         [-0.0072],
#         [-0.0102],
#         [-0.0234],
#         [-0.0166],
#         [ 0.0009],
#         [-0.0037],
#         [-0.0075],
#         [ 0.0042],
#         [-0.0144],
#         [-0.0281],
#         [-0.0143],
#         [-0.0231],
#         [-0.0089],
#         [ 0.0052],
#         [-0.0063],
#         [-0.0083],
#         [ 0.0064],
#         [-0.0120],
#         [-0.0098],
#         [ 0.0077],
#         [-0.0055],
#         [-0.0227],
#         [-0.0307],
#         [-0.0374],
#         [-0.0388],
#         [-0.0278],
#         [-0.0210],
#         [-0.0020],
#         [ 0.0006],
#         [ 0.0028],
#         [ 0.0017],
#         [ 0.0017],
#         [ 0.0056],
#         [ 0.0057],
#         [-0.0004],
#         [ 0.0038],
#         [ 0.0066],
#         [ 0.0262],
#         [ 0.0251],
#         [ 0.0335],
#         [ 0.0265],
#         [ 0.0289],
#         [-0.0031],
#         [ 0.0147],
#         [ 0.0128],
#         [ 0.0138],
#         [-0.0001],
#         [ 0.0128],
#         [-0.0020],
#         [-0.0002],
#         [-0.0039],
#         [ 0.0035]])
# torch.Size([56, 1]) tensor([[-0.0047],
#         [-0.0184],
#         [-0.0154],
#         [ 0.0060],
#         [ 0.0013],
#         [ 0.0027],
#         [-0.0098],
#         [-0.0219],
#         [-0.0371],
#         [-0.0279],
#         [-0.0299],
#         [-0.0127],
#         [-0.0088],
#         [-0.0075],
#         [ 0.0133],
#         [ 0.0176],
#         [ 0.0317],
#         [ 0.0460],
#         [ 0.0470],
#         [ 0.0385],
#         [ 0.0360],
#         [ 0.0340],
#         [ 0.0298],
#         [ 0.0481],
#         [ 0.0614],
#         [ 0.0957],
#         [ 0.1218],
#         [ 0.1072],
#         [ 0.0890],
#         [ 0.0579],
#         [ 0.0047],
#         [-0.0185],
#         [-0.0235],
#         [-0.0016],
#         [ 0.0120],
#         [ 0.0538],
#         [ 0.0650],
#         [ 0.0803],
#         [ 0.0565],
#         [ 0.0165],
#         [ 0.0154],
#         [-0.0113],
#         [-0.0183],
#         [ 0.0134],
#         [ 0.0321],
#         [-0.0059],
#         [-0.0012],
#         [ 0.0111],
#         [-0.0332],
#         [-0.0343],
#         [-0.0110],
#         [-0.0100],
#         [-0.0336],
#         [-0.0471],
#         [-0.0339],
#         [-0.0383]])
# Epoch: 0 Train MSE: 63.30207 Val MSE: 17.36210  Time: 5.091
# torch.Size([128, 1]) tensor([[-5.5402e-03],
#         [-1.3774e-03],
#         [-6.2979e-03],
#         [ 1.9106e-02],
#         [ 3.1378e-03],
#         [ 5.0244e-03],
#         [ 2.1851e-02],
#         [-3.7390e-04],
#         [-2.5859e-02],
#         [-2.0908e-03],
#         [-2.6135e-02],
#         [-2.0957e-02],
#         [ 2.9913e-04],
#         [ 2.2163e-02],
#         [ 1.0854e-02],
#         [ 2.8049e-02],
#         [ 2.2487e-02],
#         [ 2.9978e-02],
#         [ 8.1127e-03],
#         [-7.3945e-05],
#         [-2.5411e-03],
#         [-2.3343e-02],
#         [-2.6023e-02],
#         [-1.0337e-02],
#         [ 4.2062e-03],
#         [-7.8109e-03],
#         [ 6.7570e-03],
#         [ 4.9775e-03],
#         [-1.8571e-03],
#         [-1.8426e-03],
#         [ 7.2577e-03],
#         [-7.6515e-03],
#         [ 1.1850e-03],
#         [ 1.0776e-03],
#         [ 1.1060e-03],
#         [-6.8861e-03],
#         [-7.7856e-03],
#         [-1.8527e-02],
#         [-1.7495e-02],
#         [-5.6543e-02],
#         [-3.1933e-02],
#         [-2.7814e-02],
#         [-3.0159e-02],
#         [-1.2091e-02],
#         [ 1.5936e-02],
#         [-9.2092e-03],
#         [ 9.9955e-03],
#         [ 6.4294e-03],
#         [-2.7580e-03],
#         [ 4.1739e-03],
#         [-1.6659e-03],
#         [-1.9468e-02],
#         [-8.7635e-03],
#         [-2.4148e-02],
#         [-1.3813e-02],
#         [-6.7697e-03],
#         [-4.4564e-03],
#         [-9.0767e-03],
#         [-1.5720e-04],
#         [-1.4282e-02],
#         [-5.1664e-03],
#         [ 2.6606e-03],
#         [ 1.0999e-03],
#         [ 1.0999e-03],
#         [-6.3082e-03],
#         [-2.5032e-02],
#         [-2.8055e-02],
#         [-2.9563e-02],
#         [-3.0655e-02],
#         [-2.4746e-02],
#         [-1.8272e-02],
#         [-4.6306e-02],
#         [-9.5569e-02],
#         [-8.3503e-02],
#         [-6.6806e-02],
#         [-6.6409e-02],
#         [-3.7307e-02],
#         [ 3.1877e-02],
#         [ 2.7247e-03],
#         [-3.8708e-02],
#         [-1.4201e-02],
#         [-4.8152e-02],
#         [-4.9743e-02],
#         [-4.7360e-02],
#         [-1.4427e-03],
#         [-1.8560e-02],
#         [ 4.7628e-02],
#         [ 3.7908e-02],
#         [ 5.5577e-02],
#         [ 2.3014e-02],
#         [ 2.8988e-02],
#         [-2.0180e-02],
#         [-2.1600e-02],
#         [ 1.5223e-03],
#         [ 1.4706e-02],
#         [ 1.3361e-02],
#         [ 9.7653e-03],
#         [ 2.6255e-02],
#         [ 2.4309e-03],
#         [-8.0266e-03],
#         [-1.3889e-02],
#         [ 2.4478e-02],
#         [ 7.5244e-03],
#         [ 2.5892e-02],
#         [ 3.7143e-02],
#         [ 4.1522e-02],
#         [ 7.1725e-03],
#         [ 1.0031e-02],
#         [-1.0277e-02],
#         [-2.7120e-02],
#         [-5.3302e-03],
#         [-9.1572e-03],
#         [-1.8423e-02],
#         [ 1.7059e-03],
#         [ 2.0005e-02],
#         [-5.0603e-03],
#         [ 2.8464e-03],
#         [-1.0306e-02],
#         [ 2.0858e-03],
#         [ 3.2038e-02],
#         [ 4.7496e-02],
#         [ 6.1627e-02],
#         [ 7.6694e-02],
#         [ 5.2394e-02],
#         [ 8.2291e-04],
#         [-7.0170e-03],
#         [-1.7895e-02],
#         [-1.3342e-02]])
# torch.Size([128, 1]) tensor([[-3.1522e-02],
#         [-1.2457e-02],
#         [-1.7053e-02],
#         [ 3.2925e-03],
#         [-6.6553e-03],
#         [ 1.9554e-03],
#         [ 8.7485e-03],
#         [-3.3321e-04],
#         [-2.1513e-02],
#         [-1.1177e-02],
#         [ 8.6903e-03],
#         [ 2.1443e-03],
#         [-2.5861e-03],
#         [-2.0171e-03],
#         [-9.9050e-03],
#         [-2.0733e-02],
#         [-6.2810e-03],
#         [ 1.3977e-02],
#         [ 3.1307e-02],
#         [ 4.3191e-02],
#         [ 6.8522e-02],
#         [ 6.1180e-02],
#         [ 5.4735e-02],
#         [ 5.5470e-02],
#         [ 3.6134e-02],
#         [ 6.0310e-03],
#         [-3.1243e-03],
#         [-6.7293e-03],
#         [-5.4532e-03],
#         [ 3.2424e-03],
#         [ 5.0745e-04],
#         [ 3.6310e-03],
#         [ 7.8508e-05],
#         [-3.7376e-02],
#         [-3.1054e-02],
#         [-2.4853e-02],
#         [-4.1173e-02],
#         [-3.4015e-02],
#         [-1.7299e-02],
#         [-2.1882e-02],
#         [-2.5527e-02],
#         [-2.4793e-02],
#         [-2.3254e-02],
#         [-1.2281e-02],
#         [-1.3080e-02],
#         [-3.0883e-02],
#         [-1.3116e-02],
#         [-1.2675e-02],
#         [-1.2140e-02],
#         [ 3.8672e-03],
#         [-7.1791e-03],
#         [-5.8378e-03],
#         [-2.6403e-02],
#         [-3.9599e-02],
#         [-5.0693e-02],
#         [-2.2026e-02],
#         [-4.3442e-02],
#         [-2.5788e-02],
#         [ 6.6156e-03],
#         [-5.6775e-04],
#         [ 3.1330e-03],
#         [ 1.8091e-02],
#         [ 2.5788e-02],
#         [-1.4326e-03],
#         [ 7.4858e-03],
#         [ 4.1189e-03],
#         [-1.7408e-04],
#         [-3.6624e-02],
#         [-7.6862e-02],
#         [-4.5189e-02],
#         [-2.8349e-02],
#         [-2.9326e-02],
#         [-4.4845e-04],
#         [ 3.9553e-02],
#         [-4.5374e-04],
#         [-1.3940e-02],
#         [-2.1427e-02],
#         [-2.0803e-02],
#         [-2.0363e-02],
#         [-3.0879e-02],
#         [-5.2874e-02],
#         [-3.9842e-02],
#         [-5.3767e-02],
#         [-2.7197e-02],
#         [-4.5977e-03],
#         [-9.5179e-05],
#         [-4.7765e-03],
#         [ 7.5109e-03],
#         [-1.0793e-02],
#         [-2.8136e-02],
#         [-1.4574e-02],
#         [-1.1073e-02],
#         [ 1.6035e-02],
#         [-2.3262e-02],
#         [ 1.2084e-03],
#         [ 0.0000e+00],
#         [-1.3080e-03],
#         [-3.6338e-02],
#         [-1.4887e-02],
#         [-3.5350e-02],
#         [-1.0095e-02],
#         [-1.8296e-02],
#         [-2.7342e-02],
#         [ 1.2633e-02],
#         [-6.5271e-03],
#         [ 9.9020e-03],
#         [ 1.6307e-02],
#         [ 3.5095e-02],
#         [-2.9959e-03],
#         [ 3.4362e-02],
#         [ 1.6859e-02],
#         [-2.9673e-03],
#         [ 3.1522e-03],
#         [ 5.4044e-02],
#         [ 4.6642e-02],
#         [ 2.8559e-02],
#         [ 4.9145e-02],
#         [ 3.1879e-02],
#         [-7.9249e-04],
#         [ 9.7504e-04],
#         [-2.0329e-03],
#         [-6.1448e-02],
#         [-5.0992e-02],
#         [-3.4975e-02],
#         [-3.7159e-02],
#         [-4.0202e-02],
#         [ 2.4746e-02],
#         [ 1.6253e-02]])
# torch.Size([128, 1]) tensor([[ 2.5510e-02],
#         [ 2.6287e-02],
#         [ 1.8178e-02],
#         [ 2.0478e-02],
#         [ 1.1586e-02],
#         [-1.9971e-02],
#         [-2.8070e-02],
#         [-8.6897e-03],
#         [-2.2935e-02],
#         [-1.3449e-03],
#         [ 4.5523e-03],
#         [ 5.6775e-03],
#         [-1.9164e-02],
#         [-1.0424e-02],
#         [-1.1845e-02],
#         [-1.6924e-02],
#         [-1.2553e-02],
#         [-2.3960e-02],
#         [-2.6871e-02],
#         [-3.3129e-02],
#         [-4.0032e-02],
#         [-3.7522e-02],
#         [-3.7543e-02],
#         [-3.3549e-02],
#         [-5.7688e-02],
#         [-4.9914e-02],
#         [-6.7391e-02],
#         [-3.8846e-02],
#         [-4.7336e-02],
#         [-3.9434e-02],
#         [-1.5981e-02],
#         [-1.5607e-02],
#         [ 0.0000e+00],
#         [-3.1534e-03],
#         [ 1.9042e-02],
#         [ 4.0463e-03],
#         [ 1.3145e-03],
#         [-1.9648e-02],
#         [ 4.3469e-03],
#         [-9.0642e-03],
#         [-1.1153e-02],
#         [ 3.2787e-03],
#         [ 6.2292e-03],
#         [ 1.9330e-02],
#         [ 2.2937e-02],
#         [-8.4749e-03],
#         [ 4.8980e-03],
#         [-1.0183e-02],
#         [-3.4093e-03],
#         [ 1.4793e-02],
#         [ 2.1941e-02],
#         [ 2.3712e-02],
#         [ 3.1952e-02],
#         [ 1.1733e-03],
#         [-9.0201e-03],
#         [ 1.5617e-02],
#         [ 4.0740e-03],
#         [ 3.2460e-03],
#         [ 3.2460e-03],
#         [-1.7040e-02],
#         [-1.8037e-02],
#         [-2.4642e-02],
#         [-3.9389e-02],
#         [-4.8604e-02],
#         [-5.1850e-02],
#         [-6.6972e-02],
#         [-5.1470e-02],
#         [-2.3370e-02],
#         [-3.5191e-02],
#         [-5.7102e-05],
#         [ 1.6616e-02],
#         [-7.3772e-03],
#         [ 2.9372e-03],
#         [ 2.7746e-02],
#         [ 9.3214e-03],
#         [ 2.9242e-02],
#         [ 5.3801e-02],
#         [ 2.3908e-02],
#         [ 2.6778e-02],
#         [ 3.3819e-02],
#         [ 1.9230e-03],
#         [ 9.1503e-03],
#         [ 3.2934e-02],
#         [ 1.3745e-02],
#         [ 9.2006e-03],
#         [-8.9321e-03],
#         [-4.1487e-02],
#         [-5.1947e-02],
#         [-2.7682e-02],
#         [-8.8725e-03],
#         [ 1.0358e-02],
#         [ 3.0649e-02],
#         [ 2.6912e-02],
#         [ 2.5738e-02],
#         [ 2.6970e-02],
#         [ 1.8841e-02],
#         [ 1.2669e-02],
#         [ 7.2945e-03],
#         [ 1.9382e-02],
#         [ 1.7016e-03],
#         [ 1.7119e-02],
#         [ 3.1873e-02],
#         [ 5.3899e-02],
#         [ 6.6065e-02],
#         [ 6.2255e-02],
#         [ 3.1284e-02],
#         [ 3.0282e-02],
#         [ 7.5773e-03],
#         [-1.0027e-02],
#         [-7.2651e-03],
#         [ 1.7727e-02],
#         [ 1.0106e-03],
#         [ 3.8915e-02],
#         [ 1.7494e-02],
#         [ 2.3360e-02],
#         [ 2.4174e-02],
#         [ 4.3340e-03],
#         [-2.3629e-02],
#         [-1.9401e-02],
#         [-2.2254e-02],
#         [-3.3685e-02],
#         [-1.3874e-02],
#         [-1.9580e-02],
#         [-2.3840e-02],
#         [-4.0544e-02],
#         [-2.5899e-02],
#         [-2.0294e-02],
#         [-4.5053e-02]])
# torch.Size([128, 1]) tensor([[-0.0412],
#         [-0.0213],
#         [-0.0009],
#         [ 0.0091],
#         [ 0.0384],
#         [ 0.0347],
#         [ 0.0360],
#         [ 0.0341],
#         [ 0.0297],
#         [ 0.0337],
#         [ 0.0436],
#         [ 0.0317],
#         [ 0.0038],
#         [-0.0164],
#         [-0.0116],
#         [ 0.0041],
#         [ 0.0115],
#         [-0.0091],
#         [-0.0069],
#         [-0.0316],
#         [-0.0482],
#         [-0.0749],
#         [-0.0493],
#         [-0.0337],
#         [-0.0371],
#         [-0.0401],
#         [-0.0105],
#         [-0.0069],
#         [-0.0202],
#         [-0.0073],
#         [-0.0103],
#         [-0.0156],
#         [-0.0080],
#         [ 0.0104],
#         [ 0.0190],
#         [ 0.0284],
#         [ 0.0308],
#         [ 0.0160],
#         [-0.0085],
#         [-0.0140],
#         [-0.0051],
#         [-0.0068],
#         [-0.0289],
#         [-0.0141],
#         [-0.0256],
#         [-0.0436],
#         [-0.0321],
#         [-0.0148],
#         [ 0.0131],
#         [ 0.0062],
#         [ 0.0101],
#         [ 0.0202],
#         [ 0.0356],
#         [ 0.0140],
#         [ 0.0533],
#         [ 0.0322],
#         [ 0.0140],
#         [ 0.0318],
#         [ 0.0289],
#         [ 0.0132],
#         [ 0.0437],
#         [ 0.0379],
#         [-0.0024],
#         [-0.0207],
#         [-0.0351],
#         [-0.0420],
#         [-0.0314],
#         [ 0.0108],
#         [ 0.0387],
#         [ 0.0519],
#         [ 0.0423],
#         [ 0.0400],
#         [ 0.0240],
#         [ 0.0072],
#         [ 0.0090],
#         [ 0.0021],
#         [-0.0072],
#         [-0.0102],
#         [-0.0234],
#         [-0.0166],
#         [ 0.0009],
#         [-0.0037],
#         [-0.0075],
#         [ 0.0042],
#         [-0.0144],
#         [-0.0281],
#         [-0.0143],
#         [-0.0231],
#         [-0.0089],
#         [ 0.0052],
#         [-0.0063],
#         [-0.0083],
#         [ 0.0064],
#         [-0.0120],
#         [-0.0098],
#         [ 0.0077],
#         [-0.0055],
#         [-0.0227],
#         [-0.0307],
#         [-0.0374],
#         [-0.0388],
#         [-0.0278],
#         [-0.0210],
#         [-0.0020],
#         [ 0.0006],
#         [ 0.0028],
#         [ 0.0017],
#         [ 0.0017],
#         [ 0.0056],
#         [ 0.0057],
#         [-0.0004],
#         [ 0.0038],
#         [ 0.0066],
#         [ 0.0262],
#         [ 0.0251],
#         [ 0.0335],
#         [ 0.0265],
#         [ 0.0289],
#         [-0.0031],
#         [ 0.0147],
#         [ 0.0128],
#         [ 0.0138],
#         [-0.0001],
#         [ 0.0128],
#         [-0.0020],
#         [-0.0002],
#         [-0.0039],
#         [ 0.0035]])
# torch.Size([56, 1]) tensor([[-0.0047],
#         [-0.0184],
#         [-0.0154],
#         [ 0.0060],
#         [ 0.0013],
#         [ 0.0027],
#         [-0.0098],
#         [-0.0219],
#         [-0.0371],
#         [-0.0279],
#         [-0.0299],
#         [-0.0127],
#         [-0.0088],
#         [-0.0075],
#         [ 0.0133],
#         [ 0.0176],
#         [ 0.0317],
#         [ 0.0460],
#         [ 0.0470],
#         [ 0.0385],
#         [ 0.0360],
#         [ 0.0340],
#         [ 0.0298],
#         [ 0.0481],
#         [ 0.0614],
#         [ 0.0957],
#         [ 0.1218],
#         [ 0.1072],
#         [ 0.0890],
#         [ 0.0579],
#         [ 0.0047],
#         [-0.0185],
#         [-0.0235],
#         [-0.0016],
#         [ 0.0120],
#         [ 0.0538],
#         [ 0.0650],
#         [ 0.0803],
#         [ 0.0565],
#         [ 0.0165],
#         [ 0.0154],
#         [-0.0113],
#         [-0.0183],
#         [ 0.0134],
#         [ 0.0321],
#         [-0.0059],
#         [-0.0012],
#         [ 0.0111],
#         [-0.0332],
#         [-0.0343],
#         [-0.0110],
#         [-0.0100],
#         [-0.0336],
#         [-0.0471],
#         [-0.0339],
#         [-0.0383]])
# torch.Size([128, 1]) tensor([[-5.5402e-03],
#         [-1.3774e-03],
#         [-6.2979e-03],
#         [ 1.9106e-02],
#         [ 3.1378e-03],
#         [ 5.0244e-03],
#         [ 2.1851e-02],
#         [-3.7390e-04],
#         [-2.5859e-02],
#         [-2.0908e-03],
#         [-2.6135e-02],
#         [-2.0957e-02],
#         [ 2.9913e-04],
#         [ 2.2163e-02],
#         [ 1.0854e-02],
#         [ 2.8049e-02],
#         [ 2.2487e-02],
#         [ 2.9978e-02],
#         [ 8.1127e-03],
#         [-7.3945e-05],
#         [-2.5411e-03],
#         [-2.3343e-02],
#         [-2.6023e-02],
#         [-1.0337e-02],
#         [ 4.2062e-03],
#         [-7.8109e-03],
#         [ 6.7570e-03],
#         [ 4.9775e-03],
#         [-1.8571e-03],
#         [-1.8426e-03],
#         [ 7.2577e-03],
#         [-7.6515e-03],
#         [ 1.1850e-03],
#         [ 1.0776e-03],
#         [ 1.1060e-03],
#         [-6.8861e-03],
#         [-7.7856e-03],
#         [-1.8527e-02],
#         [-1.7495e-02],
#         [-5.6543e-02],
#         [-3.1933e-02],
#         [-2.7814e-02],
#         [-3.0159e-02],
#         [-1.2091e-02],
#         [ 1.5936e-02],
#         [-9.2092e-03],
#         [ 9.9955e-03],
#         [ 6.4294e-03],
#         [-2.7580e-03],
#         [ 4.1739e-03],
#         [-1.6659e-03],
#         [-1.9468e-02],
#         [-8.7635e-03],
#         [-2.4148e-02],
#         [-1.3813e-02],
#         [-6.7697e-03],
#         [-4.4564e-03],
#         [-9.0767e-03],
#         [-1.5720e-04],
#         [-1.4282e-02],
#         [-5.1664e-03],
#         [ 2.6606e-03],
#         [ 1.0999e-03],
#         [ 1.0999e-03],
#         [-6.3082e-03],
#         [-2.5032e-02],
#         [-2.8055e-02],
#         [-2.9563e-02],
#         [-3.0655e-02],
#         [-2.4746e-02],
#         [-1.8272e-02],
#         [-4.6306e-02],
#         [-9.5569e-02],
#         [-8.3503e-02],
#         [-6.6806e-02],
#         [-6.6409e-02],
#         [-3.7307e-02],
#         [ 3.1877e-02],
#         [ 2.7247e-03],
#         [-3.8708e-02],
#         [-1.4201e-02],
#         [-4.8152e-02],
#         [-4.9743e-02],
#         [-4.7360e-02],
#         [-1.4427e-03],
#         [-1.8560e-02],
#         [ 4.7628e-02],
#         [ 3.7908e-02],
#         [ 5.5577e-02],
#         [ 2.3014e-02],
#         [ 2.8988e-02],
#         [-2.0180e-02],
#         [-2.1600e-02],
#         [ 1.5223e-03],
#         [ 1.4706e-02],
#         [ 1.3361e-02],
#         [ 9.7653e-03],
#         [ 2.6255e-02],
#         [ 2.4309e-03],
#         [-8.0266e-03],
#         [-1.3889e-02],
#         [ 2.4478e-02],
#         [ 7.5244e-03],
#         [ 2.5892e-02],
#         [ 3.7143e-02],
#         [ 4.1522e-02],
#         [ 7.1725e-03],
#         [ 1.0031e-02],
#         [-1.0277e-02],
#         [-2.7120e-02],
#         [-5.3302e-03],
#         [-9.1572e-03],
#         [-1.8423e-02],
#         [ 1.7059e-03],
#         [ 2.0005e-02],
#         [-5.0603e-03],
#         [ 2.8464e-03],
#         [-1.0306e-02],
#         [ 2.0858e-03],
#         [ 3.2038e-02],
#         [ 4.7496e-02],
#         [ 6.1627e-02],
#         [ 7.6694e-02],
#         [ 5.2394e-02],
#         [ 8.2291e-04],
#         [-7.0170e-03],
#         [-1.7895e-02],
#         [-1.3342e-02]])
# torch.Size([128, 1]) tensor([[-3.1522e-02],
#         [-1.2457e-02],
#         [-1.7053e-02],
#         [ 3.2925e-03],
#         [-6.6553e-03],
#         [ 1.9554e-03],
#         [ 8.7485e-03],
#         [-3.3321e-04],
#         [-2.1513e-02],
#         [-1.1177e-02],
#         [ 8.6903e-03],
#         [ 2.1443e-03],
#         [-2.5861e-03],
#         [-2.0171e-03],
#         [-9.9050e-03],
#         [-2.0733e-02],
#         [-6.2810e-03],
#         [ 1.3977e-02],
#         [ 3.1307e-02],
#         [ 4.3191e-02],
#         [ 6.8522e-02],
#         [ 6.1180e-02],
#         [ 5.4735e-02],
#         [ 5.5470e-02],
#         [ 3.6134e-02],
#         [ 6.0310e-03],
#         [-3.1243e-03],
#         [-6.7293e-03],
#         [-5.4532e-03],
#         [ 3.2424e-03],
#         [ 5.0745e-04],
#         [ 3.6310e-03],
#         [ 7.8508e-05],
#         [-3.7376e-02],
#         [-3.1054e-02],
#         [-2.4853e-02],
#         [-4.1173e-02],
#         [-3.4015e-02],
#         [-1.7299e-02],
#         [-2.1882e-02],
#         [-2.5527e-02],
#         [-2.4793e-02],
#         [-2.3254e-02],
#         [-1.2281e-02],
#         [-1.3080e-02],
#         [-3.0883e-02],
#         [-1.3116e-02],
#         [-1.2675e-02],
#         [-1.2140e-02],
#         [ 3.8672e-03],
#         [-7.1791e-03],
#         [-5.8378e-03],
#         [-2.6403e-02],
#         [-3.9599e-02],
#         [-5.0693e-02],
#         [-2.2026e-02],
#         [-4.3442e-02],
#         [-2.5788e-02],
#         [ 6.6156e-03],
#         [-5.6775e-04],
#         [ 3.1330e-03],
#         [ 1.8091e-02],
#         [ 2.5788e-02],
#         [-1.4326e-03],
#         [ 7.4858e-03],
#         [ 4.1189e-03],
#         [-1.7408e-04],
#         [-3.6624e-02],
#         [-7.6862e-02],
#         [-4.5189e-02],
#         [-2.8349e-02],
#         [-2.9326e-02],
#         [-4.4845e-04],
#         [ 3.9553e-02],
#         [-4.5374e-04],
#         [-1.3940e-02],
#         [-2.1427e-02],
#         [-2.0803e-02],
#         [-2.0363e-02],
#         [-3.0879e-02],
#         [-5.2874e-02],
#         [-3.9842e-02],
#         [-5.3767e-02],
#         [-2.7197e-02],
#         [-4.5977e-03],
#         [-9.5179e-05],
#         [-4.7765e-03],
#         [ 7.5109e-03],
#         [-1.0793e-02],
#         [-2.8136e-02],
#         [-1.4574e-02],
#         [-1.1073e-02],
#         [ 1.6035e-02],
#         [-2.3262e-02],
#         [ 1.2084e-03],
#         [ 0.0000e+00],
#         [-1.3080e-03],
#         [-3.6338e-02],
#         [-1.4887e-02],
#         [-3.5350e-02],
#         [-1.0095e-02],
#         [-1.8296e-02],
#         [-2.7342e-02],
#         [ 1.2633e-02],
#         [-6.5271e-03],
#         [ 9.9020e-03],
#         [ 1.6307e-02],
#         [ 3.5095e-02],
#         [-2.9959e-03],
#         [ 3.4362e-02],
#         [ 1.6859e-02],
#         [-2.9673e-03],
#         [ 3.1522e-03],
#         [ 5.4044e-02],
#         [ 4.6642e-02],
#         [ 2.8559e-02],
#         [ 4.9145e-02],
#         [ 3.1879e-02],
#         [-7.9249e-04],
#         [ 9.7504e-04],
#         [-2.0329e-03],
#         [-6.1448e-02],
#         [-5.0992e-02],
#         [-3.4975e-02],
#         [-3.7159e-02],
#         [-4.0202e-02],
#         [ 2.4746e-02],
#         [ 1.6253e-02]])
# torch.Size([128, 1]) tensor([[ 2.5510e-02],
#         [ 2.6287e-02],
#         [ 1.8178e-02],
#         [ 2.0478e-02],
#         [ 1.1586e-02],
#         [-1.9971e-02],
#         [-2.8070e-02],
#         [-8.6897e-03],
#         [-2.2935e-02],
#         [-1.3449e-03],
#         [ 4.5523e-03],
#         [ 5.6775e-03],
#         [-1.9164e-02],
#         [-1.0424e-02],
#         [-1.1845e-02],
#         [-1.6924e-02],
#         [-1.2553e-02],
#         [-2.3960e-02],
#         [-2.6871e-02],
#         [-3.3129e-02],
#         [-4.0032e-02],
#         [-3.7522e-02],
#         [-3.7543e-02],
#         [-3.3549e-02],
#         [-5.7688e-02],
#         [-4.9914e-02],
#         [-6.7391e-02],
#         [-3.8846e-02],
#         [-4.7336e-02],
#         [-3.9434e-02],
#         [-1.5981e-02],
#         [-1.5607e-02],
#         [ 0.0000e+00],
#         [-3.1534e-03],
#         [ 1.9042e-02],
#         [ 4.0463e-03],
#         [ 1.3145e-03],
#         [-1.9648e-02],
#         [ 4.3469e-03],
#         [-9.0642e-03],
#         [-1.1153e-02],
#         [ 3.2787e-03],
#         [ 6.2292e-03],
#         [ 1.9330e-02],
#         [ 2.2937e-02],
#         [-8.4749e-03],
#         [ 4.8980e-03],
#         [-1.0183e-02],
#         [-3.4093e-03],
#         [ 1.4793e-02],
#         [ 2.1941e-02],
#         [ 2.3712e-02],
#         [ 3.1952e-02],
#         [ 1.1733e-03],
#         [-9.0201e-03],
#         [ 1.5617e-02],
#         [ 4.0740e-03],
#         [ 3.2460e-03],
#         [ 3.2460e-03],
#         [-1.7040e-02],
#         [-1.8037e-02],
#         [-2.4642e-02],
#         [-3.9389e-02],
#         [-4.8604e-02],
#         [-5.1850e-02],
#         [-6.6972e-02],
#         [-5.1470e-02],
#         [-2.3370e-02],
#         [-3.5191e-02],
#         [-5.7102e-05],
#         [ 1.6616e-02],
#         [-7.3772e-03],
#         [ 2.9372e-03],
#         [ 2.7746e-02],
#         [ 9.3214e-03],
#         [ 2.9242e-02],
#         [ 5.3801e-02],
#         [ 2.3908e-02],
#         [ 2.6778e-02],
#         [ 3.3819e-02],
#         [ 1.9230e-03],
#         [ 9.1503e-03],
#         [ 3.2934e-02],
#         [ 1.3745e-02],
#         [ 9.2006e-03],
#         [-8.9321e-03],
#         [-4.1487e-02],
#         [-5.1947e-02],
#         [-2.7682e-02],
#         [-8.8725e-03],
#         [ 1.0358e-02],
#         [ 3.0649e-02],
#         [ 2.6912e-02],
#         [ 2.5738e-02],
#         [ 2.6970e-02],
#         [ 1.8841e-02],
#         [ 1.2669e-02],
#         [ 7.2945e-03],
#         [ 1.9382e-02],
#         [ 1.7016e-03],
#         [ 1.7119e-02],
#         [ 3.1873e-02],
#         [ 5.3899e-02],
#         [ 6.6065e-02],
#         [ 6.2255e-02],
#         [ 3.1284e-02],
#         [ 3.0282e-02],
#         [ 7.5773e-03],
#         [-1.0027e-02],
#         [-7.2651e-03],
#         [ 1.7727e-02],
#         [ 1.0106e-03],
#         [ 3.8915e-02],
#         [ 1.7494e-02],
#         [ 2.3360e-02],
#         [ 2.4174e-02],
#         [ 4.3340e-03],
#         [-2.3629e-02],
#         [-1.9401e-02],
#         [-2.2254e-02],
#         [-3.3685e-02],
#         [-1.3874e-02],
#         [-1.9580e-02],
#         [-2.3840e-02],
#         [-4.0544e-02],
#         [-2.5899e-02],
#         [-2.0294e-02],
#         [-4.5053e-02]])
# torch.Size([128, 1]) tensor([[-0.0412],
#         [-0.0213],
#         [-0.0009],
#         [ 0.0091],
#         [ 0.0384],
#         [ 0.0347],
#         [ 0.0360],
#         [ 0.0341],
#         [ 0.0297],
#         [ 0.0337],
#         [ 0.0436],
#         [ 0.0317],
#         [ 0.0038],
#         [-0.0164],
#         [-0.0116],
#         [ 0.0041],
#         [ 0.0115],
#         [-0.0091],
#         [-0.0069],
#         [-0.0316],
#         [-0.0482],
#         [-0.0749],
#         [-0.0493],
#         [-0.0337],
#         [-0.0371],
#         [-0.0401],
#         [-0.0105],
#         [-0.0069],
#         [-0.0202],
#         [-0.0073],
#         [-0.0103],
#         [-0.0156],
#         [-0.0080],
#         [ 0.0104],
#         [ 0.0190],
#         [ 0.0284],
#         [ 0.0308],
#         [ 0.0160],
#         [-0.0085],
#         [-0.0140],
#         [-0.0051],
#         [-0.0068],
#         [-0.0289],
#         [-0.0141],
#         [-0.0256],
#         [-0.0436],
#         [-0.0321],
#         [-0.0148],
#         [ 0.0131],
#         [ 0.0062],
#         [ 0.0101],
#         [ 0.0202],
#         [ 0.0356],
#         [ 0.0140],
#         [ 0.0533],
#         [ 0.0322],
#         [ 0.0140],
#         [ 0.0318],
#         [ 0.0289],
#         [ 0.0132],
#         [ 0.0437],
#         [ 0.0379],
#         [-0.0024],
#         [-0.0207],
#         [-0.0351],
#         [-0.0420],
#         [-0.0314],
#         [ 0.0108],
#         [ 0.0387],
#         [ 0.0519],
#         [ 0.0423],
#         [ 0.0400],
#         [ 0.0240],
#         [ 0.0072],
#         [ 0.0090],
#         [ 0.0021],
#         [-0.0072],
#         [-0.0102],
#         [-0.0234],
#         [-0.0166],
#         [ 0.0009],
#         [-0.0037],
#         [-0.0075],
#         [ 0.0042],
#         [-0.0144],
#         [-0.0281],
#         [-0.0143],
#         [-0.0231],
#         [-0.0089],
#         [ 0.0052],
#         [-0.0063],
#         [-0.0083],
#         [ 0.0064],
#         [-0.0120],
#         [-0.0098],
#         [ 0.0077],
#         [-0.0055],
#         [-0.0227],
#         [-0.0307],
#         [-0.0374],
#         [-0.0388],
#         [-0.0278],
#         [-0.0210],
#         [-0.0020],
#         [ 0.0006],
#         [ 0.0028],
#         [ 0.0017],
#         [ 0.0017],
#         [ 0.0056],
#         [ 0.0057],
#         [-0.0004],
#         [ 0.0038],
#         [ 0.0066],
#         [ 0.0262],
#         [ 0.0251],
#         [ 0.0335],
#         [ 0.0265],
#         [ 0.0289],
#         [-0.0031],
#         [ 0.0147],
#         [ 0.0128],
#         [ 0.0138],
#         [-0.0001],
#         [ 0.0128],
#         [-0.0020],
#         [-0.0002],
#         [-0.0039],
#         [ 0.0035]])
# torch.Size([56, 1]) tensor([[-0.0047],
#         [-0.0184],
#         [-0.0154],
#         [ 0.0060],
#         [ 0.0013],
#         [ 0.0027],
#         [-0.0098],
#         [-0.0219],
#         [-0.0371],
#         [-0.0279],
#         [-0.0299],
#         [-0.0127],
#         [-0.0088],
#         [-0.0075],
#         [ 0.0133],
#         [ 0.0176],
#         [ 0.0317],
#         [ 0.0460],
#         [ 0.0470],
#         [ 0.0385],
#         [ 0.0360],
#         [ 0.0340],
#         [ 0.0298],
#         [ 0.0481],
#         [ 0.0614],
#         [ 0.0957],
#         [ 0.1218],
#         [ 0.1072],
#         [ 0.0890],
#         [ 0.0579],
#         [ 0.0047],
#         [-0.0185],
#         [-0.0235],
#         [-0.0016],
#         [ 0.0120],
#         [ 0.0538],
#         [ 0.0650],
#         [ 0.0803],
#         [ 0.0565],
#         [ 0.0165],
#         [ 0.0154],
#         [-0.0113],
#         [-0.0183],
#         [ 0.0134],
#         [ 0.0321],
#         [-0.0059],
#         [-0.0012],
#         [ 0.0111],
#         [-0.0332],
#         [-0.0343],
#         [-0.0110],
#         [-0.0100],
#         [-0.0336],
#         [-0.0471],
#         [-0.0339],
#         [-0.0383]])
# torch.Size([128, 1]) tensor([[-5.5402e-03],
#         [-1.3774e-03],
#         [-6.2979e-03],
#         [ 1.9106e-02],
#         [ 3.1378e-03],
#         [ 5.0244e-03],
#         [ 2.1851e-02],
#         [-3.7390e-04],
#         [-2.5859e-02],
#         [-2.0908e-03],
#         [-2.6135e-02],
#         [-2.0957e-02],
#         [ 2.9913e-04],
#         [ 2.2163e-02],
#         [ 1.0854e-02],
#         [ 2.8049e-02],
#         [ 2.2487e-02],
#         [ 2.9978e-02],
#         [ 8.1127e-03],
#         [-7.3945e-05],
#         [-2.5411e-03],
#         [-2.3343e-02],
#         [-2.6023e-02],
#         [-1.0337e-02],
#         [ 4.2062e-03],
#         [-7.8109e-03],
#         [ 6.7570e-03],
#         [ 4.9775e-03],
#         [-1.8571e-03],
#         [-1.8426e-03],
#         [ 7.2577e-03],
#         [-7.6515e-03],
#         [ 1.1850e-03],
#         [ 1.0776e-03],
#         [ 1.1060e-03],
#         [-6.8861e-03],
#         [-7.7856e-03],
#         [-1.8527e-02],
#         [-1.7495e-02],
#         [-5.6543e-02],
#         [-3.1933e-02],
#         [-2.7814e-02],
#         [-3.0159e-02],
#         [-1.2091e-02],
#         [ 1.5936e-02],
#         [-9.2092e-03],
#         [ 9.9955e-03],
#         [ 6.4294e-03],
#         [-2.7580e-03],
#         [ 4.1739e-03],
#         [-1.6659e-03],
#         [-1.9468e-02],
#         [-8.7635e-03],
#         [-2.4148e-02],
#         [-1.3813e-02],
#         [-6.7697e-03],
#         [-4.4564e-03],
#         [-9.0767e-03],
#         [-1.5720e-04],
#         [-1.4282e-02],
#         [-5.1664e-03],
#         [ 2.6606e-03],
#         [ 1.0999e-03],
#         [ 1.0999e-03],
#         [-6.3082e-03],
#         [-2.5032e-02],
#         [-2.8055e-02],
#         [-2.9563e-02],
#         [-3.0655e-02],
#         [-2.4746e-02],
#         [-1.8272e-02],
#         [-4.6306e-02],
#         [-9.5569e-02],
#         [-8.3503e-02],
#         [-6.6806e-02],
#         [-6.6409e-02],
#         [-3.7307e-02],
#         [ 3.1877e-02],
#         [ 2.7247e-03],
#         [-3.8708e-02],
#         [-1.4201e-02],
#         [-4.8152e-02],
#         [-4.9743e-02],
#         [-4.7360e-02],
#         [-1.4427e-03],
#         [-1.8560e-02],
#         [ 4.7628e-02],
#         [ 3.7908e-02],
#         [ 5.5577e-02],
#         [ 2.3014e-02],
#         [ 2.8988e-02],
#         [-2.0180e-02],
#         [-2.1600e-02],
#         [ 1.5223e-03],
#         [ 1.4706e-02],
#         [ 1.3361e-02],
#         [ 9.7653e-03],
#         [ 2.6255e-02],
#         [ 2.4309e-03],
#         [-8.0266e-03],
#         [-1.3889e-02],
#         [ 2.4478e-02],
#         [ 7.5244e-03],
#         [ 2.5892e-02],
#         [ 3.7143e-02],
#         [ 4.1522e-02],
#         [ 7.1725e-03],
#         [ 1.0031e-02],
#         [-1.0277e-02],
#         [-2.7120e-02],
#         [-5.3302e-03],
#         [-9.1572e-03],
#         [-1.8423e-02],
#         [ 1.7059e-03],
#         [ 2.0005e-02],
#         [-5.0603e-03],
#         [ 2.8464e-03],
#         [-1.0306e-02],
#         [ 2.0858e-03],
#         [ 3.2038e-02],
#         [ 4.7496e-02],
#         [ 6.1627e-02],
#         [ 7.6694e-02],
#         [ 5.2394e-02],
#         [ 8.2291e-04],
#         [-7.0170e-03],
#         [-1.7895e-02],
#         [-1.3342e-02]])
# torch.Size([128, 1]) tensor([[-3.1522e-02],
#         [-1.2457e-02],
#         [-1.7053e-02],
#         [ 3.2925e-03],
#         [-6.6553e-03],
#         [ 1.9554e-03],
#         [ 8.7485e-03],
#         [-3.3321e-04],
#         [-2.1513e-02],
#         [-1.1177e-02],
#         [ 8.6903e-03],
#         [ 2.1443e-03],
#         [-2.5861e-03],
#         [-2.0171e-03],
#         [-9.9050e-03],
#         [-2.0733e-02],
#         [-6.2810e-03],
#         [ 1.3977e-02],
#         [ 3.1307e-02],
#         [ 4.3191e-02],
#         [ 6.8522e-02],
#         [ 6.1180e-02],
#         [ 5.4735e-02],
#         [ 5.5470e-02],
#         [ 3.6134e-02],
#         [ 6.0310e-03],
#         [-3.1243e-03],
#         [-6.7293e-03],
#         [-5.4532e-03],
#         [ 3.2424e-03],
#         [ 5.0745e-04],
#         [ 3.6310e-03],
#         [ 7.8508e-05],
#         [-3.7376e-02],
#         [-3.1054e-02],
#         [-2.4853e-02],
#         [-4.1173e-02],
#         [-3.4015e-02],
#         [-1.7299e-02],
#         [-2.1882e-02],
#         [-2.5527e-02],
#         [-2.4793e-02],
#         [-2.3254e-02],
#         [-1.2281e-02],
#         [-1.3080e-02],
#         [-3.0883e-02],
#         [-1.3116e-02],
#         [-1.2675e-02],
#         [-1.2140e-02],
#         [ 3.8672e-03],
#         [-7.1791e-03],
#         [-5.8378e-03],
#         [-2.6403e-02],
#         [-3.9599e-02],
#         [-5.0693e-02],
#         [-2.2026e-02],
#         [-4.3442e-02],
#         [-2.5788e-02],
#         [ 6.6156e-03],
#         [-5.6775e-04],
#         [ 3.1330e-03],
#         [ 1.8091e-02],
#         [ 2.5788e-02],
#         [-1.4326e-03],
#         [ 7.4858e-03],
#         [ 4.1189e-03],
#         [-1.7408e-04],
#         [-3.6624e-02],
#         [-7.6862e-02],
#         [-4.5189e-02],
#         [-2.8349e-02],
#         [-2.9326e-02],
#         [-4.4845e-04],
#         [ 3.9553e-02],
#         [-4.5374e-04],
#         [-1.3940e-02],
#         [-2.1427e-02],
#         [-2.0803e-02],
#         [-2.0363e-02],
#         [-3.0879e-02],
#         [-5.2874e-02],
#         [-3.9842e-02],
#         [-5.3767e-02],
#         [-2.7197e-02],
#         [-4.5977e-03],
#         [-9.5179e-05],
#         [-4.7765e-03],
#         [ 7.5109e-03],
#         [-1.0793e-02],
#         [-2.8136e-02],
#         [-1.4574e-02],
#         [-1.1073e-02],
#         [ 1.6035e-02],
#         [-2.3262e-02],
#         [ 1.2084e-03],
#         [ 0.0000e+00],
#         [-1.3080e-03],
#         [-3.6338e-02],
#         [-1.4887e-02],
#         [-3.5350e-02],
#         [-1.0095e-02],
#         [-1.8296e-02],
#         [-2.7342e-02],
#         [ 1.2633e-02],
#         [-6.5271e-03],
#         [ 9.9020e-03],
#         [ 1.6307e-02],
#         [ 3.5095e-02],
#         [-2.9959e-03],
#         [ 3.4362e-02],
#         [ 1.6859e-02],
#         [-2.9673e-03],
#         [ 3.1522e-03],
#         [ 5.4044e-02],
#         [ 4.6642e-02],
#         [ 2.8559e-02],
#         [ 4.9145e-02],
#         [ 3.1879e-02],
#         [-7.9249e-04],
#         [ 9.7504e-04],
#         [-2.0329e-03],
#         [-6.1448e-02],
#         [-5.0992e-02],
#         [-3.4975e-02],
#         [-3.7159e-02],
#         [-4.0202e-02],
#         [ 2.4746e-02],
#         [ 1.6253e-02]])
# torch.Size([128, 1]) tensor([[ 2.5510e-02],
#         [ 2.6287e-02],
#         [ 1.8178e-02],
#         [ 2.0478e-02],
#         [ 1.1586e-02],
#         [-1.9971e-02],
#         [-2.8070e-02],
#         [-8.6897e-03],
#         [-2.2935e-02],
#         [-1.3449e-03],
#         [ 4.5523e-03],
#         [ 5.6775e-03],
#         [-1.9164e-02],
#         [-1.0424e-02],
#         [-1.1845e-02],
#         [-1.6924e-02],
#         [-1.2553e-02],
#         [-2.3960e-02],
#         [-2.6871e-02],
#         [-3.3129e-02],
#         [-4.0032e-02],
#         [-3.7522e-02],
#         [-3.7543e-02],
#         [-3.3549e-02],
#         [-5.7688e-02],
#         [-4.9914e-02],
#         [-6.7391e-02],
#         [-3.8846e-02],
#         [-4.7336e-02],
#         [-3.9434e-02],
#         [-1.5981e-02],
#         [-1.5607e-02],
#         [ 0.0000e+00],
#         [-3.1534e-03],
#         [ 1.9042e-02],
#         [ 4.0463e-03],
#         [ 1.3145e-03],
#         [-1.9648e-02],
#         [ 4.3469e-03],
#         [-9.0642e-03],
#         [-1.1153e-02],
#         [ 3.2787e-03],
#         [ 6.2292e-03],
#         [ 1.9330e-02],
#         [ 2.2937e-02],
#         [-8.4749e-03],
#         [ 4.8980e-03],
#         [-1.0183e-02],
#         [-3.4093e-03],
#         [ 1.4793e-02],
#         [ 2.1941e-02],
#         [ 2.3712e-02],
#         [ 3.1952e-02],
#         [ 1.1733e-03],
#         [-9.0201e-03],
#         [ 1.5617e-02],
#         [ 4.0740e-03],
#         [ 3.2460e-03],
#         [ 3.2460e-03],
#         [-1.7040e-02],
#         [-1.8037e-02],
#         [-2.4642e-02],
#         [-3.9389e-02],
#         [-4.8604e-02],
#         [-5.1850e-02],
#         [-6.6972e-02],
#         [-5.1470e-02],
#         [-2.3370e-02],
#         [-3.5191e-02],
#         [-5.7102e-05],
#         [ 1.6616e-02],
#         [-7.3772e-03],
#         [ 2.9372e-03],
#         [ 2.7746e-02],
#         [ 9.3214e-03],
#         [ 2.9242e-02],
#         [ 5.3801e-02],
#         [ 2.3908e-02],
#         [ 2.6778e-02],
#         [ 3.3819e-02],
#         [ 1.9230e-03],
#         [ 9.1503e-03],
#         [ 3.2934e-02],
#         [ 1.3745e-02],
#         [ 9.2006e-03],
#         [-8.9321e-03],
#         [-4.1487e-02],
#         [-5.1947e-02],
#         [-2.7682e-02],
#         [-8.8725e-03],
#         [ 1.0358e-02],
#         [ 3.0649e-02],
#         [ 2.6912e-02],
#         [ 2.5738e-02],
#         [ 2.6970e-02],
#         [ 1.8841e-02],
#         [ 1.2669e-02],
#         [ 7.2945e-03],
#         [ 1.9382e-02],
#         [ 1.7016e-03],
#         [ 1.7119e-02],
#         [ 3.1873e-02],
#         [ 5.3899e-02],
#         [ 6.6065e-02],
#         [ 6.2255e-02],
#         [ 3.1284e-02],
#         [ 3.0282e-02],
#         [ 7.5773e-03],
#         [-1.0027e-02],
#         [-7.2651e-03],
#         [ 1.7727e-02],
#         [ 1.0106e-03],
#         [ 3.8915e-02],
#         [ 1.7494e-02],
#         [ 2.3360e-02],
#         [ 2.4174e-02],
#         [ 4.3340e-03],
#         [-2.3629e-02],
#         [-1.9401e-02],
#         [-2.2254e-02],
#         [-3.3685e-02],
#         [-1.3874e-02],
#         [-1.9580e-02],
#         [-2.3840e-02],
#         [-4.0544e-02],
#         [-2.5899e-02],
#         [-2.0294e-02],
#         [-4.5053e-02]])
# torch.Size([128, 1]) tensor([[-0.0412],
#         [-0.0213],
#         [-0.0009],
#         [ 0.0091],
#         [ 0.0384],
#         [ 0.0347],
#         [ 0.0360],
#         [ 0.0341],
#         [ 0.0297],
#         [ 0.0337],
#         [ 0.0436],
#         [ 0.0317],
#         [ 0.0038],
#         [-0.0164],
#         [-0.0116],
#         [ 0.0041],
#         [ 0.0115],
#         [-0.0091],
#         [-0.0069],
#         [-0.0316],
#         [-0.0482],
#         [-0.0749],
#         [-0.0493],
#         [-0.0337],
#         [-0.0371],
#         [-0.0401],
#         [-0.0105],
#         [-0.0069],
#         [-0.0202],
#         [-0.0073],
#         [-0.0103],
#         [-0.0156],
#         [-0.0080],
#         [ 0.0104],
#         [ 0.0190],
#         [ 0.0284],
#         [ 0.0308],
#         [ 0.0160],
#         [-0.0085],
#         [-0.0140],
#         [-0.0051],
#         [-0.0068],
#         [-0.0289],
#         [-0.0141],
#         [-0.0256],
#         [-0.0436],
#         [-0.0321],
#         [-0.0148],
#         [ 0.0131],
#         [ 0.0062],
#         [ 0.0101],
#         [ 0.0202],
#         [ 0.0356],
#         [ 0.0140],
#         [ 0.0533],
#         [ 0.0322],
#         [ 0.0140],
#         [ 0.0318],
#         [ 0.0289],
#         [ 0.0132],
#         [ 0.0437],
#         [ 0.0379],
#         [-0.0024],
#         [-0.0207],
#         [-0.0351],
#         [-0.0420],
#         [-0.0314],
#         [ 0.0108],
#         [ 0.0387],
#         [ 0.0519],
#         [ 0.0423],
#         [ 0.0400],
#         [ 0.0240],
#         [ 0.0072],
#         [ 0.0090],
#         [ 0.0021],
#         [-0.0072],
#         [-0.0102],
#         [-0.0234],
#         [-0.0166],
#         [ 0.0009],
#         [-0.0037],
#         [-0.0075],
#         [ 0.0042],
#         [-0.0144],
#         [-0.0281],
#         [-0.0143],
#         [-0.0231],
#         [-0.0089],
#         [ 0.0052],
#         [-0.0063],
#         [-0.0083],
#         [ 0.0064],
#         [-0.0120],
#         [-0.0098],
#         [ 0.0077],
#         [-0.0055],
#         [-0.0227],
#         [-0.0307],
#         [-0.0374],
#         [-0.0388],
#         [-0.0278],
#         [-0.0210],
#         [-0.0020],
#         [ 0.0006],
#         [ 0.0028],
#         [ 0.0017],
#         [ 0.0017],
#         [ 0.0056],
#         [ 0.0057],
#         [-0.0004],
#         [ 0.0038],
#         [ 0.0066],
#         [ 0.0262],
#         [ 0.0251],
#         [ 0.0335],
#         [ 0.0265],
#         [ 0.0289],
#         [-0.0031],
#         [ 0.0147],
#         [ 0.0128],
#         [ 0.0138],
#         [-0.0001],
#         [ 0.0128],
#         [-0.0020],
#         [-0.0002],
#         [-0.0039],
#         [ 0.0035]])
# torch.Size([56, 1]) tensor([[-0.0047],
#         [-0.0184],
#         [-0.0154],
#         [ 0.0060],
#         [ 0.0013],
#         [ 0.0027],
#         [-0.0098],
#         [-0.0219],
#         [-0.0371],
#         [-0.0279],
#         [-0.0299],
#         [-0.0127],
#         [-0.0088],
#         [-0.0075],
#         [ 0.0133],
#         [ 0.0176],
#         [ 0.0317],
#         [ 0.0460],
#         [ 0.0470],
#         [ 0.0385],
#         [ 0.0360],
#         [ 0.0340],
#         [ 0.0298],
#         [ 0.0481],
#         [ 0.0614],
#         [ 0.0957],
#         [ 0.1218],
#         [ 0.1072],
#         [ 0.0890],
#         [ 0.0579],
#         [ 0.0047],
#         [-0.0185],
#         [-0.0235],
#         [-0.0016],
#         [ 0.0120],
#         [ 0.0538],
#         [ 0.0650],
#         [ 0.0803],
#         [ 0.0565],
#         [ 0.0165],
#         [ 0.0154],
#         [-0.0113],
#         [-0.0183],
#         [ 0.0134],
#         [ 0.0321],
#         [-0.0059],
#         [-0.0012],
#         [ 0.0111],
#         [-0.0332],
#         [-0.0343],
#         [-0.0110],
#         [-0.0100],
#         [-0.0336],
#         [-0.0471],
#         [-0.0339],
#         [-0.0383]])
# torch.Size([128, 1]) tensor([[-5.5402e-03],
#         [-1.3774e-03],
#         [-6.2979e-03],
#         [ 1.9106e-02],
#         [ 3.1378e-03],
#         [ 5.0244e-03],
#         [ 2.1851e-02],
#         [-3.7390e-04],
#         [-2.5859e-02],
#         [-2.0908e-03],
#         [-2.6135e-02],
#         [-2.0957e-02],
#         [ 2.9913e-04],
#         [ 2.2163e-02],
#         [ 1.0854e-02],
#         [ 2.8049e-02],
#         [ 2.2487e-02],
#         [ 2.9978e-02],
#         [ 8.1127e-03],
#         [-7.3945e-05],
#         [-2.5411e-03],
#         [-2.3343e-02],
#         [-2.6023e-02],
#         [-1.0337e-02],
#         [ 4.2062e-03],
#         [-7.8109e-03],
#         [ 6.7570e-03],
#         [ 4.9775e-03],
#         [-1.8571e-03],
#         [-1.8426e-03],
#         [ 7.2577e-03],
#         [-7.6515e-03],
#         [ 1.1850e-03],
#         [ 1.0776e-03],
#         [ 1.1060e-03],
#         [-6.8861e-03],
#         [-7.7856e-03],
#         [-1.8527e-02],
#         [-1.7495e-02],
#         [-5.6543e-02],
#         [-3.1933e-02],
#         [-2.7814e-02],
#         [-3.0159e-02],
#         [-1.2091e-02],
#         [ 1.5936e-02],
#         [-9.2092e-03],
#         [ 9.9955e-03],
#         [ 6.4294e-03],
#         [-2.7580e-03],
#         [ 4.1739e-03],
#         [-1.6659e-03],
#         [-1.9468e-02],
#         [-8.7635e-03],
#         [-2.4148e-02],
#         [-1.3813e-02],
#         [-6.7697e-03],
#         [-4.4564e-03],
#         [-9.0767e-03],
#         [-1.5720e-04],
#         [-1.4282e-02],
#         [-5.1664e-03],
#         [ 2.6606e-03],
#         [ 1.0999e-03],
#         [ 1.0999e-03],
#         [-6.3082e-03],
#         [-2.5032e-02],
#         [-2.8055e-02],
#         [-2.9563e-02],
#         [-3.0655e-02],
#         [-2.4746e-02],
#         [-1.8272e-02],
#         [-4.6306e-02],
#         [-9.5569e-02],
#         [-8.3503e-02],
#         [-6.6806e-02],
#         [-6.6409e-02],
#         [-3.7307e-02],
#         [ 3.1877e-02],
#         [ 2.7247e-03],
#         [-3.8708e-02],
#         [-1.4201e-02],
#         [-4.8152e-02],
#         [-4.9743e-02],
#         [-4.7360e-02],
#         [-1.4427e-03],
#         [-1.8560e-02],
#         [ 4.7628e-02],
#         [ 3.7908e-02],
#         [ 5.5577e-02],
#         [ 2.3014e-02],
#         [ 2.8988e-02],
#         [-2.0180e-02],
#         [-2.1600e-02],
#         [ 1.5223e-03],
#         [ 1.4706e-02],
#         [ 1.3361e-02],
#         [ 9.7653e-03],
#         [ 2.6255e-02],
#         [ 2.4309e-03],
#         [-8.0266e-03],
#         [-1.3889e-02],
#         [ 2.4478e-02],
#         [ 7.5244e-03],
#         [ 2.5892e-02],
#         [ 3.7143e-02],
#         [ 4.1522e-02],
#         [ 7.1725e-03],
#         [ 1.0031e-02],
#         [-1.0277e-02],
#         [-2.7120e-02],
#         [-5.3302e-03],
#         [-9.1572e-03],
#         [-1.8423e-02],
#         [ 1.7059e-03],
#         [ 2.0005e-02],
#         [-5.0603e-03],
#         [ 2.8464e-03],
#         [-1.0306e-02],
#         [ 2.0858e-03],
#         [ 3.2038e-02],
#         [ 4.7496e-02],
#         [ 6.1627e-02],
#         [ 7.6694e-02],
#         [ 5.2394e-02],
#         [ 8.2291e-04],
#         [-7.0170e-03],
#         [-1.7895e-02],
#         [-1.3342e-02]])
# torch.Size([128, 1]) tensor([[-3.1522e-02],
#         [-1.2457e-02],
#         [-1.7053e-02],
#         [ 3.2925e-03],
#         [-6.6553e-03],
#         [ 1.9554e-03],
#         [ 8.7485e-03],
#         [-3.3321e-04],
#         [-2.1513e-02],
#         [-1.1177e-02],
#         [ 8.6903e-03],
#         [ 2.1443e-03],
#         [-2.5861e-03],
#         [-2.0171e-03],
#         [-9.9050e-03],
#         [-2.0733e-02],
#         [-6.2810e-03],
#         [ 1.3977e-02],
#         [ 3.1307e-02],
#         [ 4.3191e-02],
#         [ 6.8522e-02],
#         [ 6.1180e-02],
#         [ 5.4735e-02],
#         [ 5.5470e-02],
#         [ 3.6134e-02],
#         [ 6.0310e-03],
#         [-3.1243e-03],
#         [-6.7293e-03],
#         [-5.4532e-03],
#         [ 3.2424e-03],
#         [ 5.0745e-04],
#         [ 3.6310e-03],
#         [ 7.8508e-05],
#         [-3.7376e-02],
#         [-3.1054e-02],
#         [-2.4853e-02],
#         [-4.1173e-02],
#         [-3.4015e-02],
#         [-1.7299e-02],
#         [-2.1882e-02],
#         [-2.5527e-02],
#         [-2.4793e-02],
#         [-2.3254e-02],
#         [-1.2281e-02],
#         [-1.3080e-02],
#         [-3.0883e-02],
#         [-1.3116e-02],
#         [-1.2675e-02],
#         [-1.2140e-02],
#         [ 3.8672e-03],
#         [-7.1791e-03],
#         [-5.8378e-03],
#         [-2.6403e-02],
#         [-3.9599e-02],
#         [-5.0693e-02],
#         [-2.2026e-02],
#         [-4.3442e-02],
#         [-2.5788e-02],
#         [ 6.6156e-03],
#         [-5.6775e-04],
#         [ 3.1330e-03],
#         [ 1.8091e-02],
#         [ 2.5788e-02],
#         [-1.4326e-03],
#         [ 7.4858e-03],
#         [ 4.1189e-03],
#         [-1.7408e-04],
#         [-3.6624e-02],
#         [-7.6862e-02],
#         [-4.5189e-02],
#         [-2.8349e-02],
#         [-2.9326e-02],
#         [-4.4845e-04],
#         [ 3.9553e-02],
#         [-4.5374e-04],
#         [-1.3940e-02],
#         [-2.1427e-02],
#         [-2.0803e-02],
#         [-2.0363e-02],
#         [-3.0879e-02],
#         [-5.2874e-02],
#         [-3.9842e-02],
#         [-5.3767e-02],
#         [-2.7197e-02],
#         [-4.5977e-03],
#         [-9.5179e-05],
#         [-4.7765e-03],
#         [ 7.5109e-03],
#         [-1.0793e-02],
#         [-2.8136e-02],
#         [-1.4574e-02],
#         [-1.1073e-02],
#         [ 1.6035e-02],
#         [-2.3262e-02],
#         [ 1.2084e-03],
#         [ 0.0000e+00],
#         [-1.3080e-03],
#         [-3.6338e-02],
#         [-1.4887e-02],
#         [-3.5350e-02],
#         [-1.0095e-02],
#         [-1.8296e-02],
#         [-2.7342e-02],
#         [ 1.2633e-02],
#         [-6.5271e-03],
#         [ 9.9020e-03],
#         [ 1.6307e-02],
#         [ 3.5095e-02],
#         [-2.9959e-03],
#         [ 3.4362e-02],
#         [ 1.6859e-02],
#         [-2.9673e-03],
#         [ 3.1522e-03],
#         [ 5.4044e-02],
#         [ 4.6642e-02],
#         [ 2.8559e-02],
#         [ 4.9145e-02],
#         [ 3.1879e-02],
#         [-7.9249e-04],
#         [ 9.7504e-04],
#         [-2.0329e-03],
#         [-6.1448e-02],
#         [-5.0992e-02],
#         [-3.4975e-02],
#         [-3.7159e-02],
#         [-4.0202e-02],
#         [ 2.4746e-02],
#         [ 1.6253e-02]])
# torch.Size([128, 1]) tensor([[ 2.5510e-02],
#         [ 2.6287e-02],
#         [ 1.8178e-02],
#         [ 2.0478e-02],
#         [ 1.1586e-02],
#         [-1.9971e-02],
#         [-2.8070e-02],
#         [-8.6897e-03],
#         [-2.2935e-02],
#         [-1.3449e-03],
#         [ 4.5523e-03],
#         [ 5.6775e-03],
#         [-1.9164e-02],
#         [-1.0424e-02],
#         [-1.1845e-02],
#         [-1.6924e-02],
#         [-1.2553e-02],
#         [-2.3960e-02],
#         [-2.6871e-02],
#         [-3.3129e-02],
#         [-4.0032e-02],
#         [-3.7522e-02],
#         [-3.7543e-02],
#         [-3.3549e-02],
#         [-5.7688e-02],
#         [-4.9914e-02],
#         [-6.7391e-02],
#         [-3.8846e-02],
#         [-4.7336e-02],
#         [-3.9434e-02],
#         [-1.5981e-02],
#         [-1.5607e-02],
#         [ 0.0000e+00],
#         [-3.1534e-03],
#         [ 1.9042e-02],
#         [ 4.0463e-03],
#         [ 1.3145e-03],
#         [-1.9648e-02],
#         [ 4.3469e-03],
#         [-9.0642e-03],
#         [-1.1153e-02],
#         [ 3.2787e-03],
#         [ 6.2292e-03],
#         [ 1.9330e-02],
#         [ 2.2937e-02],
#         [-8.4749e-03],
#         [ 4.8980e-03],
#         [-1.0183e-02],
#         [-3.4093e-03],
#         [ 1.4793e-02],
#         [ 2.1941e-02],
#         [ 2.3712e-02],
#         [ 3.1952e-02],
#         [ 1.1733e-03],
#         [-9.0201e-03],
#         [ 1.5617e-02],
#         [ 4.0740e-03],
#         [ 3.2460e-03],
#         [ 3.2460e-03],
#         [-1.7040e-02],
#         [-1.8037e-02],
#         [-2.4642e-02],
#         [-3.9389e-02],
#         [-4.8604e-02],
#         [-5.1850e-02],
#         [-6.6972e-02],
#         [-5.1470e-02],
#         [-2.3370e-02],
#         [-3.5191e-02],
#         [-5.7102e-05],
#         [ 1.6616e-02],
#         [-7.3772e-03],
#         [ 2.9372e-03],
#         [ 2.7746e-02],
#         [ 9.3214e-03],
#         [ 2.9242e-02],
#         [ 5.3801e-02],
#         [ 2.3908e-02],
#         [ 2.6778e-02],
#         [ 3.3819e-02],
#         [ 1.9230e-03],
#         [ 9.1503e-03],
#         [ 3.2934e-02],
#         [ 1.3745e-02],
#         [ 9.2006e-03],
#         [-8.9321e-03],
#         [-4.1487e-02],
#         [-5.1947e-02],
#         [-2.7682e-02],
#         [-8.8725e-03],
#         [ 1.0358e-02],
#         [ 3.0649e-02],
#         [ 2.6912e-02],
#         [ 2.5738e-02],
#         [ 2.6970e-02],
#         [ 1.8841e-02],
#         [ 1.2669e-02],
#         [ 7.2945e-03],
#         [ 1.9382e-02],
#         [ 1.7016e-03],
#         [ 1.7119e-02],
#         [ 3.1873e-02],
#         [ 5.3899e-02],
#         [ 6.6065e-02],
#         [ 6.2255e-02],
#         [ 3.1284e-02],
#         [ 3.0282e-02],
#         [ 7.5773e-03],
#         [-1.0027e-02],
#         [-7.2651e-03],
#         [ 1.7727e-02],
#         [ 1.0106e-03],
#         [ 3.8915e-02],
#         [ 1.7494e-02],
#         [ 2.3360e-02],
#         [ 2.4174e-02],
#         [ 4.3340e-03],
#         [-2.3629e-02],
#         [-1.9401e-02],
#         [-2.2254e-02],
#         [-3.3685e-02],
#         [-1.3874e-02],
#         [-1.9580e-02],
#         [-2.3840e-02],
#         [-4.0544e-02],
#         [-2.5899e-02],
#         [-2.0294e-02],
#         [-4.5053e-02]])
# torch.Size([128, 1]) tensor([[-0.0412],
#         [-0.0213],
#         [-0.0009],
#         [ 0.0091],
#         [ 0.0384],
#         [ 0.0347],
#         [ 0.0360],
#         [ 0.0341],
#         [ 0.0297],
#         [ 0.0337],
#         [ 0.0436],
#         [ 0.0317],
#         [ 0.0038],
#         [-0.0164],
#         [-0.0116],
#         [ 0.0041],
#         [ 0.0115],
#         [-0.0091],
#         [-0.0069],
#         [-0.0316],
#         [-0.0482],
#         [-0.0749],
#         [-0.0493],
#         [-0.0337],
#         [-0.0371],
#         [-0.0401],
#         [-0.0105],
#         [-0.0069],
#         [-0.0202],
#         [-0.0073],
#         [-0.0103],
#         [-0.0156],
#         [-0.0080],
#         [ 0.0104],
#         [ 0.0190],
#         [ 0.0284],
#         [ 0.0308],
#         [ 0.0160],
#         [-0.0085],
#         [-0.0140],
#         [-0.0051],
#         [-0.0068],
#         [-0.0289],
#         [-0.0141],
#         [-0.0256],
#         [-0.0436],
#         [-0.0321],
#         [-0.0148],
#         [ 0.0131],
#         [ 0.0062],
#         [ 0.0101],
#         [ 0.0202],
#         [ 0.0356],
#         [ 0.0140],
#         [ 0.0533],
#         [ 0.0322],
#         [ 0.0140],
#         [ 0.0318],
#         [ 0.0289],
#         [ 0.0132],
#         [ 0.0437],
#         [ 0.0379],
#         [-0.0024],
#         [-0.0207],
#         [-0.0351],
#         [-0.0420],
#         [-0.0314],
#         [ 0.0108],
#         [ 0.0387],
#         [ 0.0519],
#         [ 0.0423],
#         [ 0.0400],
#         [ 0.0240],
#         [ 0.0072],
#         [ 0.0090],
#         [ 0.0021],
#         [-0.0072],
#         [-0.0102],
#         [-0.0234],
#         [-0.0166],
#         [ 0.0009],
#         [-0.0037],
#         [-0.0075],
#         [ 0.0042],
#         [-0.0144],
#         [-0.0281],
#         [-0.0143],
#         [-0.0231],
#         [-0.0089],
#         [ 0.0052],
#         [-0.0063],
#         [-0.0083],
#         [ 0.0064],
#         [-0.0120],
#         [-0.0098],
#         [ 0.0077],
#         [-0.0055],
#         [-0.0227],
#         [-0.0307],
#         [-0.0374],
#         [-0.0388],
#         [-0.0278],
#         [-0.0210],
#         [-0.0020],
#         [ 0.0006],
#         [ 0.0028],
#         [ 0.0017],
#         [ 0.0017],
#         [ 0.0056],
#         [ 0.0057],
#         [-0.0004],
#         [ 0.0038],
#         [ 0.0066],
#         [ 0.0262],
#         [ 0.0251],
#         [ 0.0335],
#         [ 0.0265],
#         [ 0.0289],
#         [-0.0031],
#         [ 0.0147],
#         [ 0.0128],
#         [ 0.0138],
#         [-0.0001],
#         [ 0.0128],
#         [-0.0020],
#         [-0.0002],
#         [-0.0039],
#         [ 0.0035]])
# torch.Size([56, 1]) tensor([[-0.0047],
#         [-0.0184],
#         [-0.0154],
#         [ 0.0060],
#         [ 0.0013],
#         [ 0.0027],
#         [-0.0098],
#         [-0.0219],
#         [-0.0371],
#         [-0.0279],
#         [-0.0299],
#         [-0.0127],
#         [-0.0088],
#         [-0.0075],
#         [ 0.0133],
#         [ 0.0176],
#         [ 0.0317],
#         [ 0.0460],
#         [ 0.0470],
#         [ 0.0385],
#         [ 0.0360],
#         [ 0.0340],
#         [ 0.0298],
#         [ 0.0481],
#         [ 0.0614],
#         [ 0.0957],
#         [ 0.1218],
#         [ 0.1072],
#         [ 0.0890],
#         [ 0.0579],
#         [ 0.0047],
#         [-0.0185],
#         [-0.0235],
#         [-0.0016],
#         [ 0.0120],
#         [ 0.0538],
#         [ 0.0650],
#         [ 0.0803],
#         [ 0.0565],
#         [ 0.0165],
#         [ 0.0154],
#         [-0.0113],
#         [-0.0183],
#         [ 0.0134],
#         [ 0.0321],
#         [-0.0059],
#         [-0.0012],
#         [ 0.0111],
#         [-0.0332],
#         [-0.0343],
#         [-0.0110],
#         [-0.0100],
#         [-0.0336],
#         [-0.0471],
#         [-0.0339],
#         [-0.0383]])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-7b87393c4928> in <module>
#      15 # Splitting the data into the train, validation and test sets
#      16 learning.train_val_test()
# ---> 17 learning.training_wrapper()
#
# <ipython-input-91-bb694938ffc4> in training_wrapper(self)
#     289             live_logs = {}
#     290
# --> 291             train_loss = self.train(train_loader)
#     292             val_loss = self.validate(val_loader)
#     293
#
# <ipython-input-91-bb694938ffc4> in train(self, train_data_loader)
#     214
#     215             # Perform backward pass
# --> 216             loss.backward()
#     217
#     218             # Adding the predictions for this batch to prediction list
#
# /anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# /anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
for batch_idx, (data, target) in enumerate(train_loader):
    if batch_idx == 1: 
        print("data:", data.shape, 
             "target:", target.shape)
        
    print(batch_idx)
# Out:
# 0
# data: torch.Size([105, 100, 2]) target: torch.Size([105])
# 1

# %% [markdown]
# ### Plotting

# %%
# learning.logs['Validation Loss']

# %%
predicted = learning.pred_list
observed = learning.y_train.numpy()

# %%
plt.title("Predicted vs Observed Values")
plt.plot(predicted, label="Predicted")
plt.plot(observed, label="Observed")
plt.legend()
plt.show()

plt.figure()
plt.title("Loss Plots")
plt.plot(learning.logs['Training Loss'], label="Training Loss")
plt.plot(learning.logs['Validation Loss'], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Non class runthrough

# %%
X_train = learning.X_train
X_test = learning.X_test
y_train = learning.y_train
y_test = learning.y_test

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([1900, 100, 2])
# torch.Size([1900, 1])

# %%
for batch_idx, (data, target) in enumerate(train_loader):
    if batch_idx == 1: 
        print("data:", data.shape, 
             "target:", target.shape)
        
    print(batch_idx)
# Out:
# 0
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# 1
# 2
# 3
# 4
# 5

# %%
dset = TensorDataset(X_train, y_train)

train_loader = DataLoader(dset,
                          batch_size=batch_size,
                          shuffle=False)

# %%
model_001= LSTM(num_features=num_features, 
             hidden_dim=hidden_dim, 
             series_length = series_length,
             batch_size=batch_size,
             output_dim=output_dim, 
             num_layers=num_layers)

model_001.parameters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-203-357da4de5b68> in <module>
#       4              batch_size=batch_size,
#       5              output_dim=output_dim,
# ----> 6              num_layers=num_layers)
#       7
#       8 model_001.parameters
#
# TypeError: __init__() got an unexpected keyword argument 'num_features'

# %%
from torch.autograd import Variable

class LSTM(nn.Module):
    def __init__(self, hidden_size=64, hidden_size2=128, features=2, dropout=0.2, n_layers=8, T=10):
        """
        Constructor of the LSTM based NN for time series prediction

        :param hidden_size: int, size of the first hidden layer
        :param hidden_size2: int, size of second hidden layer
        :param num_securities: int, number of stocks being predicted at the same time
        :param dropout: float, dropout value
        :param n_layers: int, number of layers
        :param T:
        """
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.hidden_size2 = hidden_size2
        self.rnn = nn.LSTM(
            input_size=features,
            hidden_size=self.hidden_size,
            num_layers=n_layers,
            dropout=dropout,
            bidirectional=False
        )

        self.fc1 = nn.Linear(self.hidden_size, self.hidden_size)
        self.fc1.weight.data.normal_()
        self.fc3 = nn.Linear(self.hidden_size, 10)
        # Changed to only one output
        self.fc2 = nn.Linear(10, 1)
        self.relu = nn.ReLU()
        self.T = T

    def forward(self, x):
        """
        forward function for LSTM net.
        :param x: Pytorch Variable, T x batch_size x n_stocks
        :return:
        """
        batch_size = x.size()[1]
        seq_length = x.size()[0]

#         print("batch, ", batch_size, 'sequence', seq_length)
        x = x.view(seq_length, batch_size, -1)  # just to be sure of the dimensions
        
        # Initial cell states
        h0 = Variable(torch.zeros(self.rnn.num_layers, batch_size, self.hidden_size))
        c0 = Variable(torch.zeros(self.rnn.num_layers, batch_size, self.hidden_size))
        outputs, (ht, ct) = self.rnn(x, (h0, c0))
        out = outputs[-1]  # last prediction
        out = self.fc1(out)
        out = self.fc3(out)
        out = self.relu(out)
        out = self.fc2(out)
        return out

    
model_stocks = LSTM(features=2)

# %%
from torch import optim
from torch.optim import lr_scheduler

# Parameters
learning_rate = 0.001
batch_size = 128
display_step = 10
n_hidden1 = 128
n_hidden2 = 128
num_epochs = 100

# %%
dset = TensorDataset(X_train, y_train)

train_loader = DataLoader(dset,
                          batch_size=batch_size,
                          shuffle=False)

# %%
for batch_idx, (data, target) in enumerate(train_loader):
    if batch_idx == 0: 
        print("data:", data.shape, 
         "target:", target.shape)
    print(batch_idx)
# Out:
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# 0
# 1

# %%
# Network Definition + Optimizer + Scheduler
optimizer = optim.RMSprop(model_stocks.parameters(), lr=learning_rate, weight_decay=0.0)  # n
scheduler_model = lr_scheduler.StepLR(optimizer, step_size=1, gamma=1.0)

# loss function
criterion = nn.MSELoss(size_average=True)
# Store successive losses
losses = []
it = 0
for i in range(num_epochs):
    loss_ = 0.
    # Store current predictions
    predicted = []
    gt = []
    # Go through training data set
    for batch_idx, (data, target) in enumerate(train_loader):
        #print(batch_idx)
        if batch_idx == 0: 
            print("data:", data.shape, 
             "target:", target.shape)
                
        data = data.permute(1, 0, 2).contiguous()

        if target.size()[0] == batch_size:
            # Set optimizer gradient to 0
            optimizer.zero_grad()
            

            # Compute predictions
            output = model_stocks(data)
            loss = criterion(output, target)
            loss_ += loss.data.item()
            # Backpropagation
            loss.backward()
            # Gradient descent step
            optimizer.step()

            for k in range(batch_size):
                predicted.append(output.data[k, 0])
                gt.append(target[k])
        it += 1

    print("Epoch = ", i)
    print("Loss = ", loss_)
    losses.append(loss_)

    scheduler_model.step()

    # Visual check
    # Plot current predictions
    if i % 5 == 0:
        predicted = np.array(predicted)
        gt = np.array(gt)
        x = np.array(range(predicted.shape[0]))
        
        plt.figure()
        plt.plot(x, predicted, label="predictions")
        plt.plot(x, gt, label="true")
        plt.legend()
        plt.show()
# Out:
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  0
# Loss =  3.547161566093564
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  1
# Loss =  0.077058469876647
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  2
# Loss =  0.07623093435540795
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  3
# Loss =  0.07561144512146711
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  4
# Loss =  0.07568076066672802
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  5
# Loss =  0.07532834354788065
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  6
# Loss =  0.07503754831850529
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  7
# Loss =  0.07531486544758081
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  8
# Loss =  0.07521314779296517
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  9
# Loss =  0.075067647267133
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  10
# Loss =  0.07472065882757306
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  11
# Loss =  0.07485432550311089
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  12
# Loss =  0.0746761355549097
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  13
# Loss =  0.07467264821752906
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  14
# Loss =  0.07472510496154428
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  15
# Loss =  0.07464035553857684
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  16
# Loss =  0.07483687112107873
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  17
# Loss =  0.07464775815606117
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  18
# Loss =  0.07505805045366287
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  19
# Loss =  0.07485195761546493
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  20
# Loss =  0.0745054124854505
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  21
# Loss =  0.07487971382215619
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  22
# Loss =  0.07492110971361399
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  23
# Loss =  0.07497866312041879
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  24
# Loss =  0.07510749576613307
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  25
# Loss =  0.07510554417967796
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  26
# Loss =  0.07514757849276066
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  27
# Loss =  0.07516392134130001
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  28
# Loss =  0.07524394476786256
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  29
# Loss =  0.07497446518391371
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  30
# Loss =  0.07535165455192327
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  31
# Loss =  0.07511368300765753
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  32
# Loss =  0.07516747713088989
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  33
# Loss =  0.07537533715367317
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  34
# Loss =  0.0753768146969378
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  35
# Loss =  0.07526793144643307
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  36
# Loss =  0.07551408931612968
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  37
# Loss =  0.07532200310379267
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  38
# Loss =  0.07564516086131334
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  39
# Loss =  0.07557378290221095
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  40
# Loss =  0.07516783708706498
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  41
# Loss =  0.07577786827459931
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  42
# Loss =  0.07564024580642581
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  43
# Loss =  0.07596993399783969
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  44
# Loss =  0.07569124642759562
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  45
# Loss =  0.07583789667114615
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  46
# Loss =  0.07575287343934178
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  47
# Loss =  0.07587874960154295
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  48
# Loss =  0.07617186196148396
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  49
# Loss =  0.07597343949601054
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  50
# Loss =  0.07602654676884413
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  51
# Loss =  0.07615160150453448
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  52
# Loss =  0.07673479476943612
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  53
# Loss =  0.0762711688876152
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  54
# Loss =  0.07642760453745723
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  55
# Loss =  0.07666421495378017
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  56
# Loss =  0.07656062208116055
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  57
# Loss =  0.07659587077796459
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  58
# Loss =  0.07654522033408284
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  59
# Loss =  0.07672103540971875
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  60
# Loss =  0.07701940275728703
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  61
# Loss =  0.07684543961659074
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  62
# Loss =  0.07690832763910294
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  63
# Loss =  0.07700480101630092
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  64
# Loss =  0.07688807649537921
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  65
# Loss =  0.07697154674679041
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  66
# Loss =  0.07712615188211203
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  67
# Loss =  0.0771583653986454
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  68
# Loss =  0.07731515169143677
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  69
# Loss =  0.07733571156859398
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  70
# Loss =  0.07706992095336318
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  71
# Loss =  0.07756623160094023
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  72
# Loss =  0.07726913364604115
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  73
# Loss =  0.07718513067811728
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  74
# Loss =  0.0772963403724134
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  75
# Loss =  0.07738689426332712
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  76
# Loss =  0.0777024831622839
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  77
# Loss =  0.07761067990213633
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  78
# Loss =  0.07774554053321481
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  79
# Loss =  0.07793392334133387
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  80
# Loss =  0.0779537120833993
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  81
# Loss =  0.07787558063864708
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  82
# Loss =  0.0779866031371057
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  83
# Loss =  0.07798737939447165
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  84
# Loss =  0.07790436316281557
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  85
# Loss =  0.07799352798610926
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  86
# Loss =  0.07799826608970761
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  87
# Loss =  0.07804579986259341
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  88
# Loss =  0.07831005938351154
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  89
# Loss =  0.07845962885767221
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  90
# Loss =  0.07864790270105004
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  91
# Loss =  0.07817361503839493
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  92
# Loss =  0.07834646990522742
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  93
# Loss =  0.07799934130162
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  94
# Loss =  0.07744818041101098
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  95
# Loss =  0.0764905740506947
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  96
# Loss =  0.07517006294801831
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  97
# Loss =  0.0746976057998836
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  98
# Loss =  0.07520396914333105
# data: torch.Size([128, 100, 2]) target: torch.Size([128])
# Epoch =  99
# Loss =  0.07468215795233846

# %%
num_epochs = 20

# Training Log
log = np.zeros(num_epochs)
# Loss Function
loss_fn = torch.nn.MSELoss(size_average=False)
# Learning rate
learning_rate = 1e-3
optimiser = torch.optim.Adam(model_stocks.parameters(), learning_rate)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser)

observed_list = []
start_time = time.time()

for epoch in range(num_epochs):
    
    pred_list = []
    
    for batch_idx, (X_train_batch, y_train_batch) in enumerate(train_loader):

        if epoch == 0: 
            observed_list.append(y_train_batch)
            
        # Zero out gradients
        optimiser.zero_grad()
        
        # Need to set seed here to make deterministic
        set_seed(42)
            
        # Forward pass
        y_pred = model_stocks(X_train_batch)
        
        # Loss Function
        loss = loss_fn(y_pred, y_train_batch)
        log[epoch] = loss.item()

        # Backward pass
        loss.backward()

        # Update parameters
        optimiser.step()
        
        pred_list.append(y_pred)
    
    if epoch % 1 == 0: print("Epoch: %i MSE: %.5f Time: %.3f" % (epoch, loss.item(), (time.time() - start_time)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-597c9bffa14d> in <module>
#      28
#      29         # Forward pass
# ---> 30         y_pred = model_stocks(X_train_batch)
#      31
#      32         # Loss Function
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-61-6b26f602894a> in forward(self, x)
#      47         h0 = Variable(torch.zeros(self.rnn.num_layers, batch_size, self.hidden_size))
#      48         c0 = Variable(torch.zeros(self.rnn.num_layers, batch_size, self.hidden_size))
# ---> 49         outputs, (ht, ct) = self.rnn(x, (h0, c0))
#      50         out = outputs[-1]  # last prediction
#      51         out = self.fc1(out)
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     557             return self.forward_packed(input, hx)
#     558         else:
# --> 559             return self.forward_tensor(input, hx)
#     560
#     561
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     537         unsorted_indices = None
#     538
# --> 539         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     540
#     541         return output, self.permute_hidden(hidden, unsorted_indices)
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     520         if batch_sizes is None:
#     521             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 522                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     523         else:
#     524             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plotting

# %%
predicted = [single_pred for batch in pred_list for single_pred in batch.detach().numpy()]
observed = [single_pred for batch in observed_list for single_pred in batch.detach().numpy()]

# %%
plt.plot(predicted, label="Predicted")
plt.plot(observed, label="Observed")
plt.legend()
plt.show()

plt.figure()
plt.plot(log, label="Training Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Data for a toy case

# %%
# batch_size = 40
batch_size = 80

# %%
X_train = torch.load('Data/Examples/X_train.pt').permute(1, 0, 2)
X_test = torch.load('Data/Examples/X_test.pt').permute(1, 0, 2)
y_train = torch.load('Data/Examples/y_train.pt')
y_test = torch.load('Data/Examples/y_test.pt')

y_train = y_train + 10
y_test = y_test + 10

# %%
print(X_train.shape)
# 80 series
# 20 is the length of a series
# 1 feature

# X_train [number of series, length of series, feature number]
# y_train [number of series]
# Out:
# torch.Size([80, 20, 1])

# %%
dset = TensorDataset(X_train, y_train)

# %%
train_loader = DataLoader(dset,
                          batch_size=batch_size,
                          shuffle=False)

# %%
model_toy = LSTM(num_features=1, 
             hidden_dim=64, 
             batch_size=batch_size,
             output_dim=1, 
             num_layers=2, 
             series_length=20)

# %%
# num_epochs = 10
num_epochs = 10000

log = np.zeros(num_epochs)
loss_fn = torch.nn.MSELoss(size_average=False)
learning_rate = 1e-3
optimiser = torch.optim.Adam(model_toy.parameters(), learning_rate)

observed_list = []
start_time = time.time()


def plot_pred_obs(predicted, observed_list):
    x_axis = np.array(range(len(predicted)))
    observed = [single_pred for batch in observed_list for single_pred in batch.detach().numpy()]

    plt.plot(x_axis, np.array(predicted), label="Predicted")
    plt.plot(x_axis, observed, label="Observed")
    plt.legend()
    plt.show()
    
    
for epoch in range(num_epochs):
    
    predicted = []
    
    for batch_idx, (X_train_batch, y_train_batch) in enumerate(train_loader):
            
        if epoch == 0: observed_list.append(y_train_batch)
            
        # Zero out gradients
        optimiser.zero_grad()
        
        # Need to set seed here to make deterministic
        set_seed(42)
        
        # Forward pass
        y_pred = model_toy(X_train_batch)
        
        # Adding the predicted values to a list for plotting
        for pred_ix in range(y_pred.size()[0]):
            predicted.append(y_pred[pred_ix].item())

        # Loss Function
        loss = loss_fn(y_pred, y_train_batch)
        log[epoch] = loss.item()

        # Backward pass
        loss.backward()

        # Update parameters
        optimiser.step()
        
    if epoch % 100 == 0: print("Epoch: %i MSE: %.5f Time: %.3f" % (epoch, loss.item(), (time.time() - start_time)))
        
    if epoch % 500.0 == 0: plot_pred_obs(predicted, observed_list)
# Out:
# Epoch: 0 MSE: 0.47888 Time: 0.086
# Epoch: 100 MSE: 3.10281 Time: 4.747
# Epoch: 200 MSE: 1.34765 Time: 9.631
# Epoch: 300 MSE: 0.77203 Time: 14.088
# Epoch: 400 MSE: 0.31594 Time: 19.185
# Epoch: 500 MSE: 0.33704 Time: 24.218
# Epoch: 600 MSE: 0.15027 Time: 30.151
# Epoch: 700 MSE: 0.11721 Time: 35.303
# Epoch: 800 MSE: 0.10723 Time: 40.471
# Epoch: 900 MSE: 0.06109 Time: 45.711
# Epoch: 1000 MSE: 0.04839 Time: 51.244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-167-050054f06d61> in <module>
#      36
#      37         # Forward pass
# ---> 38         y_pred = model_toy(X_train_batch)
#      39
#      40         # Adding the predicted values to a list for plotting
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-158-01fc7e5865ec> in forward(self, x)
#      81         # Pass through through lstm layer
#      82         # Only the x is of interest
# ---> 83         x, (hn, cn) = self.lstm(x, (h0, c0))
#      84
#      85         # Output is seq to seq but only want seq to val
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     557             return self.forward_packed(input, hx)
#     558         else:
# --> 559             return self.forward_tensor(input, hx)
#     560
#     561
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     537         unsorted_indices = None
#     538
# --> 539         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     540
#     541         return output, self.permute_hidden(hidden, unsorted_indices)
#
# /anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     520         if batch_sizes is None:
#     521             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 522                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     523         else:
#     524             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plotting predictions

# %% [markdown]
# ### Toy example

# %%
# predicted = [single_pred for batch in pred_list for single_pred in batch.detach().numpy()]
# observed = [single_pred for batch in observed_list for single_pred in batch.detach().numpy()]

# %%
plt.plot(np.array(predicted), label="Predicted")
plt.plot(observed, label="Observed")
plt.legend()
plt.show()

plt.figure()
plt.plot(log, label="Training Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting

# %% [markdown]
# ### Class Example

# %% [markdown]
# # Results

# %%
df = df_full[["target"]]
# Taking t-1 to be the value for t
df["persistance"] = df.shift(1)
df.dropna(inplace=True)
# Calculating metrics for these columns
MSE, MAE, MDE = evaluate(df, "target", "persistance")

# %%
print(df[:5])
print(df[-5:])
# Out:
#               target  persistance
# date
# 2006-09-14  0.021675    -0.001404
# 2006-09-15  0.043012     0.021675
# 2006-09-18  0.013450     0.043012
# 2006-09-19  0.025225     0.013450
# 2006-09-20  0.024843     0.025225
#               target  persistance
# date
# 2019-06-24 -0.000589     0.004104
# 2019-06-25 -0.026401    -0.000589
# 2019-06-26 -0.010480    -0.026401
# 2019-06-27 -0.011358    -0.010480
# 2019-06-28 -0.015457    -0.011358

# %%
# Placing in results dataframe
results = pd.DataFrame(columns={"MSE", "MAE", "MDE"})
results.index.name = 'Name'
results.head()
results.loc["persistance"] = [MSE, MAE, MDE] 
results.head()
# Out:
#                   MSE       MAE       MDE
# Name
# persistance  0.000582  0.017105  0.465585
